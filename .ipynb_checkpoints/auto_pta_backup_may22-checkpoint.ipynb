# %% [markdown]
# # $\Gamma^{p,X,zz}_{LM}$ in $p \in \{t,v\}$ and $X \in \{I,V,E,B\}$

# %% [markdown]
# ### Keisuke Inomata

# %%
# %matplotlib inline

# Import standard packages
import numpy as np
import matplotlib.pyplot as plt

# Import module for the functions
import functions as f
import functions_for_check as fc
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# settings for plots
plt.rcParams['font.family'] = 'Times New Roman' # font family
plt.rcParams['mathtext.fontset'] = 'stix' # math font
plt.rcParams["font.size"] = 15 # fontsize
plt.rcParams['xtick.labelsize'] = 15 # 
plt.rcParams['ytick.labelsize'] = 15 # 

plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.size'] = 6
plt.rcParams['xtick.minor.width'] = 1

plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.size'] = 6
plt.rcParams['ytick.minor.width'] = 1

plt.rcParams['xtick.direction'] = 'in' # x axis in
plt.rcParams['ytick.direction'] = 'in' # y axis in 
plt.rcParams['axes.linewidth'] = 1.0 # axis line width
plt.rcParams['axes.grid'] = True # make grid
plt.rcParams['grid.linestyle'] = 'dashed'

# %% [markdown]
# ### determine the number of plot points and lmax

# %%
div = 50 # number of points between [0, Pi]
lmax = 10 # max value of l which we take into account
epsilon = 1e-4 # regulator
x = np.arange(epsilon, np.pi, (np.pi-2*epsilon)/div) #[epsilon, Pi-epsilon]

# %% [markdown]
# ## $\Gamma^{t,X,zz}_{LM}$ (spin-2 GWs)

# %% [markdown]
# ### $\Gamma^{t,I,zz}_{LM}$

# %%
gamI00 = f.Gamma_I_zz(0,0,x,lmax)
gamI10 = f.Gamma_I_zz(1,0,x,lmax)
gamI11 = f.Gamma_I_zz(1,1,x,lmax)

# %%
gamI00_5 = f.Gamma_I_zz(0,0,x,5)
gamI10_5 = f.Gamma_I_zz(1,0,x,5)
gamI11_5 = f.Gamma_I_zz(1,1,x,5)

# %%
gamI00_exa = fc.Gamma_I_zz_exact(0,0,x)
gamI10_exa = fc.Gamma_I_zz_exact(1,0,x)
gamI11_exa = fc.Gamma_I_zz_exact(1,1,x)

# %%
plt.plot(x/np.pi*180,gamI00,label="$L=0,M=0$",lw=2.5)
plt.plot(x/np.pi*180,gamI10,label="$L=1,M=0$",lw=2.5)
plt.plot(x/np.pi*180,gamI11,label="$L=1,M=1$",lw=2.5)

plt.plot(x/np.pi*180,gamI00_5,color = 'brown',ls = 'dotted',lw=1.5)
plt.plot(x/np.pi*180,gamI10_5,color = 'brown',ls = 'dotted',lw=1.5)
plt.plot(x/np.pi*180,gamI11_5,color = 'brown',ls = 'dotted',lw=1.5)

plt.plot(x/np.pi*180,gamI00_exa,color = 'black', ls = 'dashed')
plt.plot(x/np.pi*180,gamI10_exa,color = 'black', ls = 'dashed')
plt.plot(x/np.pi*180,gamI11_exa,color = 'black', ls = 'dashed')

plt.xlim((0,180))

#plt.grid(ls = 'dashed')  
plt.xticks(np.arange(0, 181, 30))  # put x ticks at intervals of 30

plt.minorticks_on()
plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(10))
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(0.1))

plt.xlabel("$\\theta\ [\mathrm{degrees}]$")
plt.ylabel("$\Gamma^{t,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_t_I_zz_3.pdf", bbox_inches='tight')

plt.show()

# %%
plt.plot(x,gamI00,label="$L=0,M=0$",lw=2.5)
plt.plot(x,gamI10,label="$L=1,M=0$",lw=2.5)
plt.plot(x,gamI11,label="$L=1,M=1$",lw=2.5)

plt.plot(x,gamI00_5,color = 'brown',ls = 'dotted',lw=1.5)
plt.plot(x,gamI10_5,color = 'brown',ls = 'dotted',lw=1.5)
plt.plot(x,gamI11_5,color = 'brown',ls = 'dotted',lw=1.5)

plt.plot(x,gamI00_exa,color = 'black', ls = 'dashed')
plt.plot(x,gamI10_exa,color = 'black', ls = 'dashed')
plt.plot(x,gamI11_exa,color = 'black', ls = 'dashed')


plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

#plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_t_I_zz_2.pdf", bbox_inches='tight')

plt.show()

# %%
gamI20 = f.Gamma_I_zz(2,0,x,lmax)
gamI21 = f.Gamma_I_zz(2,1,x,lmax)
gamI22 = f.Gamma_I_zz(2,2,x,lmax)

# %%
gamI30 = f.Gamma_I_zz(3,0,x,lmax)
gamI31 = f.Gamma_I_zz(3,1,x,lmax)
gamI32 = f.Gamma_I_zz(3,2,x,lmax)
gamI33 = f.Gamma_I_zz(3,3,x,lmax)

# %%
gamI30_exa = fc.Gamma_I_zz_exact(3,0,x)
gamI31_exa = fc.Gamma_I_zz_exact(3,1,x)
gamI32_exa = fc.Gamma_I_zz_exact(3,2,x)
gamI33_exa = fc.Gamma_I_zz_exact(3,3,x)

# %%
#plt.plot(x/np.pi*180,gamI00,label="$L=0,M=0$",lw=2.5)
#plt.plot(x/np.pi*180,gamI10,label="$L=1,M=0$",lw=2.5)
#plt.plot(x/np.pi*180,gamI11,label="$L=1,M=1$",lw=2.5)
plt.plot(x/np.pi*180,gamI20,label="$L=2,M=0$",lw=2.5)
plt.plot(x/np.pi*180,gamI21,label="$L=2,M=1$",lw=2.5)
plt.plot(x/np.pi*180,gamI22,label="$L=2,M=2$",lw=2.5)

plt.plot(x/np.pi*180,gamI30,label="$L=3,M=0$",lw=2.5)
plt.plot(x/np.pi*180,gamI31,label="$L=3,M=1$",lw=2.5)
plt.plot(x/np.pi*180,gamI32,label="$L=3,M=2$",lw=2.5)
plt.plot(x/np.pi*180,gamI33,label="$L=3,M=3$",lw=2.5)

#plt.plot(x/np.pi*180,gamI00_5,color = 'brown',ls = 'dotted',lw=1.5)
#plt.plot(x/np.pi*180,gamI10_5,color = 'brown',ls = 'dotted',lw=1.5)
#plt.plot(x/np.pi*180,gamI11_5,color = 'brown',ls = 'dotted',lw=1.5)

plt.plot(x/np.pi*180,gamI30_exa,color = 'black', ls = 'dashed')
plt.plot(x/np.pi*180,gamI31_exa,color = 'black', ls = 'dashed')
plt.plot(x/np.pi*180,gamI32_exa,color = 'black', ls = 'dashed')
plt.plot(x/np.pi*180,gamI33_exa,color = 'black', ls = 'dashed')


plt.xlim((0,180))

#plt.grid(ls = 'dashed')  
plt.xticks(np.arange(0, 181, 30))  # put x ticks at intervals of 30

plt.minorticks_on()
plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(10))
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(0.1))

plt.xlabel("$\\theta\ [\mathrm{degrees}]$")
plt.ylabel("$\Gamma^{t,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

#plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_t_I_zz_2.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ### $\Gamma^{t,V,zz}_{LM}$

# %%
gamV00 = f.Gamma_V_zz(0,0,x,lmax)
gamV10 = f.Gamma_V_zz(1,0,x,lmax)
gamV11 = f.Gamma_V_zz(1,1,x,lmax)

# %%
plt.plot(x,gamV00,label="$L=0,M=0$")
plt.plot(x,gamV10,label="$L=1,M=0$")
plt.plot(x,gamV11,label="$L=1,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,V,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %%
gamV20 = f.Gamma_V_zz(2,0,x,lmax)
gamV21 = f.Gamma_V_zz(2,1,x,lmax)
gamV22 = f.Gamma_V_zz(2,2,x,lmax)

# %%
plt.plot(x,gamV20,label="$L=2,M=0$")
plt.plot(x,gamV21,label="$L=2,M=1$")
plt.plot(x,gamV22,label="$L=2,M=2$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,V,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %% [markdown]
# ### $\Gamma^{t,E,zz}_{LM}$

# %%
gamE40 = f.Gamma_E_zz(4,0,x,lmax)
gamE41 = f.Gamma_E_zz(4,1,x,lmax)

# %%
plt.plot(x,gamE40,label="$L=4,M=0$")
plt.plot(x,gamE41,label="$L=4,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,E,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %% [markdown]
# ### $\Gamma^{t,B,zz}_{LM}$

# %%
gamB40 = f.Gamma_B_zz(4,0,x,lmax)
gamB41 = f.Gamma_B_zz(4,1,x,lmax)

# %%
plt.plot(x,gamB40,label="$L=4,M=0$")
plt.plot(x,gamB41,label="$L=4,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,B,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %%
gam40pl = (f.Gamma_B_zz(4,0,x,lmax) + f.Gamma_E_zz(4,0,x,lmax))/2
gam41pl = (f.Gamma_B_zz(4,1,x,lmax) + f.Gamma_E_zz(4,1,x,lmax))/2

# %%
gam40mi = (f.Gamma_E_zz(4,0,x,lmax) - f.Gamma_B_zz(4,0,x,lmax))/2
gam41mi = (f.Gamma_E_zz(4,1,x,lmax) - f.Gamma_B_zz(4,1,x,lmax))/2

# %%
plt.plot(x,gam40pl,label="$L=4,M=0$")
plt.plot(x,gam41pl,label="$L=4,M=1$")

plt.plot(x,gam40mi,label="$L=4,M=0$")
plt.plot(x,gam41mi,label="$L=4,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,B,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %% [markdown]
# ## $\Gamma^{v,X,zz}_{LM}$ (spin-1 GWs)

# %%
lmax2 = 40

# %% [markdown]
# ### $\Gamma^{v,I,zz}_{LM}$

# %%
gamI_v00 = f.Gamma_I_zz_v(0,0,x,lmax2)
gamI_v10 = f.Gamma_I_zz_v(1,0,x,lmax2)
gamI_v11 = f.Gamma_I_zz_v(1,1,x,lmax2)

# %%
gamI_v00_20 = f.Gamma_I_zz_v(0,0,x,20)
gamI_v10_20 = f.Gamma_I_zz_v(1,0,x,20)
gamI_v11_20 = f.Gamma_I_zz_v(1,1,x,20)

# %%
gamI_v00_exa = fc.Gamma_I_zz_v_exact(0,0,x)
gamI_v10_exa = fc.Gamma_I_zz_v_exact(1,0,x)
gamI_v11_exa = fc.Gamma_I_zz_v_exact(1,1,x)

# %%
plt.plot(x/np.pi*180,gamI_v00,label="$L=0,M=0$",lw=2.5)
plt.plot(x/np.pi*180,gamI_v10,label="$L=1,M=0$",lw=2.5)
plt.plot(x/np.pi*180,gamI_v11,label="$L=1,M=1$",lw=2.5)

plt.plot(x/np.pi*180,gamI_v00_20,color = 'brown',ls = 'dotted',lw=1.5)
plt.plot(x/np.pi*180,gamI_v10_20,color = 'brown',ls = 'dotted',lw=1.5)
plt.plot(x/np.pi*180,gamI_v11_20,color = 'brown',ls = 'dotted',lw=1.5)

plt.plot(x/np.pi*180,gamI_v00_exa,color='black',ls='dashed')
plt.plot(x/np.pi*180,gamI_v10_exa,color='black',ls='dashed')
plt.plot(x/np.pi*180,gamI_v11_exa,color='black',ls='dashed')

plt.xlim((0,180))
plt.ylim([-1.6,1.6])

plt.xticks(np.arange(0, 181, 30))  # put x ticks at intervals of 30

plt.minorticks_on()
plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(10))
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(0.1))

plt.xlabel("$\\theta\ [\mathrm{degrees}]$")
plt.ylabel("$\Gamma^{v,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

#plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_v_I_zz_3.pdf", bbox_inches='tight')

plt.show()

# %%
gamI_v20 = f.Gamma_I_zz_v(2,0,x,lmax2)
gamI_v21 = f.Gamma_I_zz_v(2,1,x,lmax2)
gamI_v22 = f.Gamma_I_zz_v(2,2,x,lmax2)

# %%
gamI_v30 = f.Gamma_I_zz_v(3,0,x,lmax2)
gamI_v31 = f.Gamma_I_zz_v(3,1,x,lmax2)
gamI_v32 = f.Gamma_I_zz_v(3,2,x,lmax2)
gamI_v33 = f.Gamma_I_zz_v(3,3,x,lmax2)

# %%
gamI_v20_exa = fc.Gamma_I_zz_v_exact(2,0,x)
gamI_v21_exa = fc.Gamma_I_zz_v_exact(2,1,x)
gamI_v22_exa = fc.Gamma_I_zz_v_exact(2,2,x)
gamI_v30_exa = fc.Gamma_I_zz_v_exact(3,0,x)
gamI_v31_exa = fc.Gamma_I_zz_v_exact(3,1,x)
gamI_v32_exa = fc.Gamma_I_zz_v_exact(3,2,x)
gamI_v33_exa = fc.Gamma_I_zz_v_exact(3,3,x)

# %%
plt.plot(x/np.pi*180,gamI_v20,label="$L=2,M=0$",lw=2.5)
plt.plot(x/np.pi*180,gamI_v21,label="$L=2,M=1$",lw=2.5)
plt.plot(x/np.pi*180,gamI_v22,label="$L=2,M=2$",lw=2.5)

plt.plot(x/np.pi*180,gamI_v30,label="$L=3,M=0$",lw=2.5)
plt.plot(x/np.pi*180,gamI_v31,label="$L=3,M=1$",lw=2.5)
plt.plot(x/np.pi*180,gamI_v32,label="$L=3,M=2$",lw=2.5)
plt.plot(x/np.pi*180,gamI_v33,label="$L=3,M=3$",lw=2.5)

plt.plot(x/np.pi*180,gamI_v20_exa,color='black',ls='dashed')
plt.plot(x/np.pi*180,gamI_v21_exa,color='black',ls='dashed')
plt.plot(x/np.pi*180,gamI_v22_exa,color='black',ls='dashed')

plt.plot(x/np.pi*180,gamI_v30_exa,color='black',ls='dashed')
plt.plot(x/np.pi*180,gamI_v31_exa,color='black',ls='dashed')
plt.plot(x/np.pi*180,gamI_v32_exa,color='black',ls='dashed')
plt.plot(x/np.pi*180,gamI_v33_exa,color='black',ls='dashed')

plt.xlim((0,180))
plt.ylim([-1.6,1.6])

plt.xticks(np.arange(0, 181, 30))  # put x ticks at intervals of 30

plt.minorticks_on()
plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(10))
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(0.1))

plt.xlabel("$\\theta\ [\mathrm{degrees}]$")
plt.ylabel("$\Gamma^{v,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

#plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_v_I_zz_3.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ### $\Gamma^{v,V,zz}_{LM}$

# %%
gamV_v00 = f.Gamma_V_zz_v(0,0,x,lmax2)
gamV_v10 = f.Gamma_V_zz_v(1,0,x,lmax2)
gamV_v11 = f.Gamma_V_zz_v(1,1,x,lmax2)

# %%
plt.plot(x,gamV_v00,label="$L=0,M=0$")
plt.plot(x,gamV_v10,label="$L=1,M=0$")
plt.plot(x,gamV_v11,label="$L=1,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,V,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %% [markdown]
# ### $\Gamma^{v,E,zz}_{LM}$

# %%
gamE_v20 = f.Gamma_E_zz_v(2,0,x,lmax2)
gamE_v21 = f.Gamma_E_zz_v(2,1,x,lmax2)

# %%
plt.plot(x,gamE_v20,label="$L=2,M=0$")
plt.plot(x,gamE_v21,label="$L=2,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,E,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %% [markdown]
# ### $\Gamma^{v,B,zz}_{LM}$

# %%
gamB_v20 = f.Gamma_B_zz_v(2,0,x,lmax2)
gamB_v21 = f.Gamma_B_zz_v(2,1,x,lmax2)

# %%
plt.plot(x,gamB_v20,label="$L=2,M=0$")
plt.plot(x,gamB_v21,label="$L=2,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,B,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()
