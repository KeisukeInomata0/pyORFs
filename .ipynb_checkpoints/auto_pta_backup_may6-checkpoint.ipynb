# %% [markdown]
# # $\Gamma^{p,X,zz}_{LM}$ in $p \in \{t,v\}$ and $X \in \{I,V,E,B\}$

# %% [markdown]
# ### Keisuke Inomata

# %%
# %matplotlib inline

# Import standard packages
import numpy as np
import matplotlib.pyplot as plt

# Import module for the functions
import functions as f
import functions_for_check as fc
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Specifying the default setting for plots
plt.rcParams['font.family'] = 'Times New Roman' # font family
plt.rcParams['mathtext.fontset'] = 'stix' # math font
plt.rcParams["font.size"] = 15 # fontsize
plt.rcParams['xtick.labelsize'] = 15 # 
plt.rcParams['ytick.labelsize'] = 15 # 

plt.rcParams['xtick.direction'] = 'in' # x axis in
plt.rcParams['ytick.direction'] = 'in' # y axis in 
plt.rcParams['axes.linewidth'] = 1.0 # axis line width
plt.rcParams['axes.grid'] = True # make grid

# %% [markdown]
# ### determine the number of plot points and lmax

# %%
div = 50 # number of points between [0, Pi]
lmax = 10 # max value of l which we take into account
epsilon = 1e-4 # regulator
x = np.arange(epsilon, np.pi-epsilon, np.pi/div)

# %% [markdown]
# ## $\Gamma^{t,X,zz}_{LM}$ (spin-2 GWs)

# %% [markdown]
# ### $\Gamma^{t,I,zz}_{LM}$

# %%
gamI00 = f.Gamma_I_zz(0,0,x,lmax)
gamI10 = f.Gamma_I_zz(1,0,x,lmax)
gamI20 = f.Gamma_I_zz(2,0,x,lmax)
gamI11 = f.Gamma_I_zz(1,1,x,lmax)
gamI1m1 = f.Gamma_I_zz(1,-1,x,lmax)

# %%
plt.plot(x,gamI00,label="$L=0,M=0$")
plt.plot(x,gamI10,label="$L=1,M=0$")
plt.plot(x,gamI20,label="$L=2,M=0$")
plt.plot(x,gamI11,label="$L=1,M=1$")
plt.plot(x,gamI1m1,label="$L=1,M=-1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

# plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_t_I_zz.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# Convergence check on $l_\text{max}$

# %%
gamI00_5 = f.Gamma_I_zz(0,0,x,5)
gamI10_5 = f.Gamma_I_zz(1,0,x,5)
gamI20_5 = f.Gamma_I_zz(2,0,x,5)
gamI11_5 = f.Gamma_I_zz(1,1,x,5)
gamI1m1_5 = f.Gamma_I_zz(1,-1,x,5)

# %%
gamI00_exa = fc.Gamma_I_zz_exact(0,0,x)
gamI10_exa = fc.Gamma_I_zz_exact(1,0,x)
gamI11_exa = fc.Gamma_I_zz_exact(1,1,x)
gamI20_exa = fc.Gamma_I_zz_exact(2,0,x)
gamI1m1_exa = fc.Gamma_I_zz_exact(1,-1,x)
gamI22_exa = fc.Gamma_I_zz_exact(2,2,x)
gamI2m2_exa = fc.Gamma_I_zz_exact(2,-2,x)
gamI3m3_exa = fc.Gamma_I_zz_exact(3,-3,x)

# %%
plt.plot(x,gamI00,label="$L=0,M=0$",lw=2.5)
plt.plot(x,gamI10,label="$L=1,M=0$",lw=2.5)
#plt.plot(x,gamI20,label="$L=2,M=0$")
plt.plot(x,gamI11,label="$L=1,M=1$",lw=2.5)
#plt.plot(x,gamI1m1,label="$L=1,M=-1$")

plt.plot(x,gamI00_5,color = 'brown',ls = 'dotted',lw=1.5)
plt.plot(x,gamI10_5,color = 'brown',ls = 'dotted',lw=1.5)
#plt.plot(x,gamI20_5,ls = 'dotted', color = 'brown')
plt.plot(x,gamI11_5,color = 'brown',ls = 'dotted',lw=1.5)
#plt.plot(x,gamI1m1_5,ls = 'dotted', color = 'brown')

plt.plot(x,gamI00_exa,color = 'black', ls = 'dashed')
plt.plot(x,gamI10_exa,color = 'black', ls = 'dashed')
#plt.plot(x,gamI20_exa,color = 'black', ls = 'dashed')
plt.plot(x,gamI11_exa,color = 'black', ls = 'dashed')


plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_t_I_zz_2.pdf", bbox_inches='tight')

plt.show()

# %%
gamI3m3 = f.Gamma_I_zz(3,-3,x,lmax)

# %%
gamI2m2 = f.Gamma_I_zz(2,-2,x,lmax)

# %%
gamI00_exa = fc.Gamma_I_zz_exact(0,0,x)
gamI10_exa = fc.Gamma_I_zz_exact(1,0,x)
gamI11_exa = fc.Gamma_I_zz_exact(1,1,x)
gamI20_exa = fc.Gamma_I_zz_exact(2,0,x)
gamI1m1_exa = fc.Gamma_I_zz_exact(1,-1,x)
gamI22_exa = fc.Gamma_I_zz_exact(2,2,x)
gamI2m2_exa = fc.Gamma_I_zz_exact(2,-2,x)
gamI3m3_exa = fc.Gamma_I_zz_exact(3,-3,x)

# %%
plt.plot(x,gamI00,label="$L=0,M=0$")
plt.plot(x,gamI10,label="$L=1,M=0$")
plt.plot(x,gamI20,label="$L=2,M=0$")
plt.plot(x,gamI11,label="$L=1,M=1$")
plt.plot(x,gamI2m2,label="$L=2,M=-2$")
plt.plot(x,gamI3m3,label="$L=3,M=-3$")


plt.plot(x,gamI00_exa,color = 'black', ls = 'dashed')
plt.plot(x,gamI10_exa,color = 'black', ls = 'dashed')
plt.plot(x,gamI20_exa,color = 'black', ls = 'dashed')
plt.plot(x,gamI11_exa,color = 'black', ls = 'dashed')
plt.plot(x,gamI2m2_exa,color = 'black', ls = 'dashed')
plt.plot(x,gamI3m3_exa,color = 'black', ls = 'dashed')

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

# plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_t_I_zz.pdf", bbox_inches='tight')

plt.show()

# %%
gamI00_diff = (f.Gamma_I_zz(0,0,x,lmax)-f.Gamma_I_zz_exact(0,0,x))/f.Gamma_I_zz_exact(0,0,x)
gamI10_diff = (f.Gamma_I_zz(1,0,x,lmax)-f.Gamma_I_zz_exact(1,0,x))/f.Gamma_I_zz_exact(1,0,x)
gamI20_diff = (f.Gamma_I_zz(2,0,x,lmax)-f.Gamma_I_zz_exact(2,0,x))/f.Gamma_I_zz_exact(2,0,x)
gamI11_diff = (f.Gamma_I_zz(1,1,x,lmax)-f.Gamma_I_zz_exact(1,1,x))/f.Gamma_I_zz_exact(1,1,x)

# %%
plt.plot(x,gamI00_diff,label="$L=0,M=0$")
plt.plot(x,gamI10_diff,label="$L=1,M=0$")
plt.plot(x,gamI20_diff,label="$L=2,M=0$")
plt.plot(x,gamI11_diff,label="$L=1,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

# plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_t_I_zz.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ### $\Gamma^{t,V,zz}_{LM}$

# %%
gamV00 = f.Gamma_V_zz(0,0,x,lmax)
gamV11 = f.Gamma_V_zz(1,1,x,lmax)
gamV21 = f.Gamma_V_zz(2,1,x,lmax)

# %%
plt.plot(x,gamV00,label="$L=0,M=0$")
plt.plot(x,gamV11,label="$L=1,M=1$")
plt.plot(x,gamV21,label="$L=2,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,V,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %% [markdown]
# ### $\Gamma^{t,E,zz}_{LM}$

# %%
gamE30 = f.Gamma_E_zz(3,0,x,lmax)
gamE40 = f.Gamma_E_zz(4,0,x,lmax)
gamE50 = f.Gamma_E_zz(5,0,x,lmax)

# %%
plt.plot(x,gamE30,label="$L=3,M=0$")
plt.plot(x,gamE40,label="$L=4,M=0$")
plt.plot(x,gamE50,label="$L=5,M=0$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,E,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %%
gamE30_20 = f.Gamma_E_zz(3,0,x,lmax2)
gamE40_20 = f.Gamma_E_zz(4,0,x,lmax2)
gamE50_20 = f.Gamma_E_zz(5,0,x,lmax2)

# %%
plt.plot(x,gamE30,label="$L=3,M=0$")
plt.plot(x,gamE40,label="$L=4,M=0$")
plt.plot(x,gamE50,label="$L=5,M=0$")

plt.plot(x,gamE30_20,ls = 'dashed', color = 'black')
plt.plot(x,gamE40_20,ls = 'dashed', color = 'black')
plt.plot(x,gamE50_20,ls = 'dashed', color = 'black')


plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,E,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %% [markdown]
# ### $\Gamma^{t,B,zz}_{LM}$

# %%
gamB31 = f.Gamma_B_zz(3,1,x,lmax)
gamB41 = f.Gamma_B_zz(4,1,x,lmax)
gamB51 = f.Gamma_B_zz(5,1,x,lmax)

# %%
plt.plot(x,gamB31,label="$L=3,M=1$")
plt.plot(x,gamB41,label="$L=4,M=1$")
plt.plot(x,gamB51,label="$L=5,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,B,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %%
gamB31_20 = f.Gamma_B_zz(3,1,x,lmax2)
gamB41_20 = f.Gamma_B_zz(4,1,x,lmax2)
gamB51_20 = f.Gamma_B_zz(5,1,x,lmax2)

# %%
plt.plot(x,gamB31,label="$L=3,M=1$")
plt.plot(x,gamB41,label="$L=4,M=1$")
plt.plot(x,gamB51,label="$L=5,M=1$")

plt.plot(x,gamB31_20,label="$L=3,M=1$")
plt.plot(x,gamB41_20,label="$L=4,M=1$")
plt.plot(x,gamB51_20,label="$L=5,M=1$")


plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{t,B,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %% [markdown]
# ## $\Gamma^{v,X,zz}_{LM}$ (spin-1 GWs)

# %%
lmax2 = 40

# %% [markdown]
# ### $\Gamma^{v,I,zz}_{LM}$

# %%
gamI_v00 = f.Gamma_I_zz_v(0,0,x,lmax2)
gamI_v10 = f.Gamma_I_zz_v(1,0,x,lmax2)
gamI_v11 = f.Gamma_I_zz_v(1,1,x,lmax2)

# %%
plt.plot(x,gamI_v00,label="$L=0,M=0$")
plt.plot(x,gamI_v10,label="$L=1,M=0$")
plt.plot(x,gamI_v11,label="$L=1,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

#plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_v_I_zz.pdf", bbox_inches='tight')

plt.show()

# %%
gamI_v00_20 = f.Gamma_I_zz_v(0,0,x,20)
gamI_v10_20 = f.Gamma_I_zz_v(1,0,x,20)
gamI_v11_20 = f.Gamma_I_zz_v(1,1,x,20)

# %%
gamI_v00_exa = fc.Gamma_I_zz_v_exact(0,0,x)
gamI_v10_exa = fc.Gamma_I_zz_v_exact(1,0,x)
gamI_v11_exa = fc.Gamma_I_zz_v_exact(1,1,x)
gamI_v2m2_exa = fc.Gamma_I_zz_v_exact(2,-2,x)
gamI_v3m3_exa = fc.Gamma_I_zz_v_exact(3,-3,x)

# %%
plt.plot(x,gamI_v00,label="$L=0,M=0$",lw=2.5)
plt.plot(x,gamI_v10,label="$L=1,M=0$",lw=2.5)
plt.plot(x,gamI_v11,label="$L=1,M=1$",lw=2.5)

plt.plot(x,gamI_v00_20,color = 'brown',ls = 'dotted',lw=1.5)
plt.plot(x,gamI_v10_20,color = 'brown',ls = 'dotted',lw=1.5)
plt.plot(x,gamI_v11_20,color = 'brown',ls = 'dotted',lw=1.5)

plt.plot(x,gamI_v00_exa,color='black',ls='dashed')
plt.plot(x,gamI_v10_exa,color='black',ls='dashed')
plt.plot(x,gamI_v11_exa,color='black',ls='dashed')

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.ylim([-1.6,1.6])

plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_v_I_zz_2.pdf", bbox_inches='tight')

plt.show()

# %%
gamI_v2m2 = f.Gamma_I_zz_v(2,-2,x,30)
gamI_v3m3 = f.Gamma_I_zz_v(3,-3,x,30)

# %%
plt.plot(x,gamI_v00,label="$L=0,M=0$")
plt.plot(x,gamI_v10,label="$L=1,M=0$")
plt.plot(x,gamI_v11,label="$L=1,M=1$")
plt.plot(x,gamI_v2m2,label="$L=2,M=-2$")
plt.plot(x,gamI_v3m3,label="$L=3,M=-3$")

plt.plot(x,gamI_v00_exa,color='black',ls='dashed')
plt.plot(x,gamI_v10_exa,color='black',ls='dashed')
plt.plot(x,gamI_v11_exa,color='black',ls='dashed')
plt.plot(x,gamI_v2m2_exa,color='black',ls='dashed')
plt.plot(x,gamI_v3m3_exa,color='black',ls='dashed')

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.ylim([-2,2])

#plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_v_I_zz.pdf", bbox_inches='tight')

plt.show()

# %%
gamI_v00_20 = f.Gamma_I_zz_v(0,0,x,lmax2)
gamI_v10_20 = f.Gamma_I_zz_v(1,0,x,lmax2)
gamI_v11_20 = f.Gamma_I_zz_v(1,1,x,lmax2)

# %%
gamI_v00_30 = f.Gamma_I_zz_v(0,0,x,30)
gamI_v10_30 = f.Gamma_I_zz_v(1,0,x,30)
gamI_v11_30 = f.Gamma_I_zz_v(1,1,x,30)

# %%
gamI_v00_40 = f.Gamma_I_zz_v(0,0,x,40)
gamI_v10_40 = f.Gamma_I_zz_v(1,0,x,40)
gamI_v11_40 = f.Gamma_I_zz_v(1,1,x,40)

# %%
gamI_v00_80 = f.Gamma_I_zz_v(0,0,x,80)
gamI_v10_80 = f.Gamma_I_zz_v(1,0,x,80)
gamI_v11_80 = f.Gamma_I_zz_v(1,1,x,80)

# %%
plt.plot(x,gamI_v00,label="$L=0,M=0$")
plt.plot(x,gamI_v10,label="$L=1,M=0$")
plt.plot(x,gamI_v11,label="$L=1,M=1$")

plt.plot(x,gamI_v00_20,label="$L=0,M=0$")
plt.plot(x,gamI_v10_20,label="$L=1,M=0$")
plt.plot(x,gamI_v11_20,label="$L=1,M=1$")

plt.plot(x,gamI_v00_30,label="$L=0,M=0$")
plt.plot(x,gamI_v10_30,label="$L=1,M=0$")
plt.plot(x,gamI_v11_30,label="$L=1,M=1$")

plt.plot(x,gamI_v00_40,label="$L=0,M=0$")
plt.plot(x,gamI_v10_40,label="$L=1,M=0$")
plt.plot(x,gamI_v11_40,label="$L=1,M=1$")

plt.plot(x,gamI_v00_80,label="$L=0,M=0$")
plt.plot(x,gamI_v10_80,label="$L=1,M=0$")
plt.plot(x,gamI_v11_80,label="$L=1,M=1$")

plt.xlim([0.5,3])
plt.ylim([-2,2])

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,I,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

#plt.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_v_I_zz.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ### $\Gamma^{v,V,zz}_{LM}$

# %%
gamV_v00 = f.Gamma_V_zz_v(0,0,x,lmax2)
gamV_v10 = f.Gamma_V_zz_v(1,0,x,lmax2)
gamV_v11 = f.Gamma_V_zz_v(1,1,x,lmax2)

# %%
plt.plot(x,gamV_v00,label="$L=0,M=0$")
plt.plot(x,gamV_v10,label="$L=1,M=0$")
plt.plot(x,gamV_v11,label="$L=1,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,V,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %%
gamV_v11_20 = f.Gamma_V_zz_v(1,1,x,20)

# %%
gamV_v11_40 = f.Gamma_V_zz_v(1,1,x,40)

# %%
plt.plot(x,gamV_v00,label="$L=0,M=0$")
plt.plot(x,gamV_v10,label="$L=1,M=0$")
plt.plot(x,gamV_v11,label="$L=1,M=1$")

plt.plot(x,gamV_v11_20,label="$L=1,M=1$")
plt.plot(x,gamV_v11_40,label="$L=1,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,V,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %% [markdown]
# ### $\Gamma^{v,E,zz}_{LM}$

# %%
gamE_v10 = f.Gamma_E_zz_v(1,0,x,lmax2)
gamE_v11 = f.Gamma_E_zz_v(1,1,x,lmax2)
gamE_v20 = f.Gamma_E_zz_v(2,0,x,lmax2)
gamE_v21 = f.Gamma_E_zz_v(2,1,x,lmax2)

# %%
plt.plot(x,gamE_v10,label="$L=1,M=0$")
plt.plot(x,gamE_v11,label="$L=1,M=1$")
plt.plot(x,gamE_v20,label="$L=2,M=0$")
plt.plot(x,gamE_v21,label="$L=2,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,E,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %%
gamE_v20_20 = f.Gamma_E_zz_v(2,0,x,20)
gamE_v21_20 = f.Gamma_E_zz_v(2,1,x,20)

# %%
gamE_v20_50 = f.Gamma_E_zz_v(2,0,x,50)
gamE_v21_50 = f.Gamma_E_zz_v(2,1,x,50)

# %%
plt.plot(x,gamE_v10,label="$L=1,M=0$")
plt.plot(x,gamE_v11,label="$L=1,M=1$")
plt.plot(x,gamE_v20,label="$L=2,M=0$")
#plt.plot(x,gamE_v21,label="$L=2,M=1$")

plt.plot(x,gamE_v20_20,label="$L=2,M=0$")
#plt.plot(x,gamE_v21_20,label="$L=2,M=1$")

plt.plot(x,gamE_v20_50,label="$L=2,M=0$")
plt.plot(x,gamE_v21_50,label="$L=2,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,E,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %% [markdown]
# ### $\Gamma^{v,B,zz}_{LM}$

# %%
gamB_v10 = f.Gamma_B_zz_v(1,0,x,lmax2)
gamB_v11 = f.Gamma_B_zz_v(1,1,x,lmax2)
gamB_v20 = f.Gamma_B_zz_v(2,0,x,lmax2)
gamB_v21 = f.Gamma_B_zz_v(2,1,x,lmax2)

# %%
gamB_v21_20 = f.Gamma_B_zz_v(2,1,x,20)

# %%
gamB_v21_40 = f.Gamma_B_zz_v(2,1,x,40)

# %%
plt.plot(x,gamB_v10,label="$L=1,M=0$")
plt.plot(x,gamB_v11,label="$L=1,M=1$")
plt.plot(x,gamB_v20,label="$L=2,M=0$")
plt.plot(x,gamB_v21,label="$L=2,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,B,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()

# %%
gamB_v21_80 = f.Gamma_B_zz_v(2,1,x,80)

# %%
plt.plot(x,gamB_v10,label="$L=1,M=0$")
plt.plot(x,gamB_v11,label="$L=1,M=1$")
plt.plot(x,gamB_v20,label="$L=2,M=0$")
plt.plot(x,gamB_v21,label="$L=2,M=1$")

#plt.plot(x,gamB_v21_20,label="$L=2,M=1$")
plt.plot(x,gamB_v21_40,label="$L=2,M=1$")
#plt.plot(x,gamB_v21_80,label="$L=2,M=1$")

plt.xlabel("$\\theta\,[\mathrm{rad}]$")
plt.ylabel("$\Gamma^{v,B,zz}_{LM}$")
plt.legend(loc='upper right',fontsize = 13)

plt.show()
