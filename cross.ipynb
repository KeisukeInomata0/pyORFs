# %% [markdown]
# # $\Gamma^{p,X,Sz}_{LM,\alpha}$ and $\Gamma^{p,X,zS}_{LM,\alpha}$ in $p \in \{t,v\}$, $X \in \{I,V,E,B\}$, $S \in \{E,B\}$, and $\alpha \in \{\theta, \phi\}$

# %% [markdown]
# ### Keisuke Inomata

# %%
# %matplotlib inline

# Import standard packages
import numpy as np
import matplotlib.pyplot as plt

# Import module for the functions
import functions as f
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Specifying the default setting for plots
plt.rcParams['font.family'] = 'Times New Roman' # font family
plt.rcParams['mathtext.fontset'] = 'stix' # math font
plt.rcParams["font.size"] = 15 # fontsize
plt.rcParams['xtick.labelsize'] = 15 # 
plt.rcParams['ytick.labelsize'] = 15 # 

plt.rcParams['xtick.direction'] = 'in' # x axis in
plt.rcParams['ytick.direction'] = 'in' # y axis in 
plt.rcParams['axes.linewidth'] = 1.0 # axis line width
plt.rcParams['axes.grid'] = True # make grid

# %% [markdown]
# ### Determine the number of plots and l_{max}

# %%
div = 50 # number of points between [0, Pi]
lmax = 10 # max value of l which we take into account
epsilon = 1e-4 # regulator
x = np.arange(epsilon, np.pi-epsilon, np.pi/div)

# %% [markdown]
# ## $\Gamma^{t,X,Sz}_{LM,\alpha}$ and $\Gamma^{t,X,zS}_{LM,\alpha}$ (spin-2 GWs)

# %% [markdown]
# ### $\Gamma^{t,X,Ez}_{LM,\alpha}$

# %% [markdown]
# #### $\Gamma^{t,I,Ez}_{LM,\alpha}$

# %%
gamI_ez_t00 = f.Gamma_I_Ez(0,0,x,lmax,0)
gamI_ez_t10 = f.Gamma_I_Ez(1,0,x,lmax,0)
gamI_ez_t11 = f.Gamma_I_Ez(1,1,x,lmax,0)

# %%
gamI_ez_p00 = f.Gamma_I_Ez(0,0,x,lmax,1)
gamI_ez_p10 = f.Gamma_I_Ez(1,0,x,lmax,1)
gamI_ez_p11 = f.Gamma_I_Ez(1,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_ez_t00,label="$L=0,M=0$")
ax1.plot(x,gamI_ez_t10,label="$L=1,M=0$")
ax1.plot(x,gamI_ez_t11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,I,Ez}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_ez_p00,label="$L=0,M=0$")
ax2.plot(x,gamI_ez_p10,label="$L=1,M=0$")
ax2.plot(x,gamI_ez_p11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,I,Ez}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


#fig.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_t_I_ez_2.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# #### $\Gamma^{t,V,Ez}_{LM,\alpha}$

# %%
gamV_ez_t00 = f.Gamma_V_Ez(0,0,x,lmax,0)
gamV_ez_t10 = f.Gamma_V_Ez(1,0,x,lmax,0)
gamV_ez_t11 = f.Gamma_V_Ez(1,1,x,lmax,0)

# %%
gamV_ez_p00 = f.Gamma_V_Ez(0,0,x,lmax,1)
gamV_ez_p10 = f.Gamma_V_Ez(1,0,x,lmax,1)
gamV_ez_p11 = f.Gamma_V_Ez(1,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_ez_t00,label="$L=0,M=0$")
ax1.plot(x,gamV_ez_t10,label="$L=1,M=0$")
ax1.plot(x,gamV_ez_t11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,V,Ez}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_ez_p00,label="$L=0,M=0$")
ax2.plot(x,gamV_ez_p10,label="$L=1,M=0$")
ax2.plot(x,gamV_ez_p11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,V,Ez}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,E,Ez}_{LM,\alpha}$

# %%
gamE_ez_t40 = f.Gamma_E_Ez(4,0,x,lmax,0)
gamE_ez_t41 = f.Gamma_E_Ez(4,1,x,lmax,0)

# %%
gamE_ez_p40 = f.Gamma_E_Ez(4,0,x,lmax,1)
gamE_ez_p41 = f.Gamma_E_Ez(4,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_ez_t40,label="$L=4,M=0$")
ax1.plot(x,gamE_ez_t41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,E,Ez}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_ez_p40,label="$L=4,M=0$")
ax2.plot(x,gamE_ez_p41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,E,Ez}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,B,Ez}_{LM,\alpha}$

# %%
gamB_ez_t40 = f.Gamma_B_Ez(4,0,x,lmax,0)
gamB_ez_t41 = f.Gamma_B_Ez(4,1,x,lmax,0)

# %%
gamB_ez_p40 = f.Gamma_B_Ez(4,0,x,lmax,1)
gamB_ez_p41 = f.Gamma_B_Ez(4,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_ez_t40,label="$L=4,M=0$")
ax1.plot(x,gamB_ez_t41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,B,Ez}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_ez_p40,label="$L=4,M=0$")
ax2.plot(x,gamB_ez_p41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,B,Ez}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# ### $\Gamma^{t,X,zE}_{LM,\alpha}$

# %% [markdown]
# #### $\Gamma^{t,I,zE}_{LM,\alpha}$

# %%
gamI_ze_t00 = f.Gamma_I_zE(0,0,x,lmax,0)
gamI_ze_t10 = f.Gamma_I_zE(1,0,x,lmax,0)
gamI_ze_t11 = f.Gamma_I_zE(1,1,x,lmax,0)

# %%
gamI_ze_p00 = f.Gamma_I_zE(0,0,x,lmax,1)
gamI_ze_p10 = f.Gamma_I_zE(1,0,x,lmax,1)
gamI_ze_p11 = f.Gamma_I_zE(1,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_ze_t00,label="$L=0,M=0$")
ax1.plot(x,gamI_ze_t10,label="$L=1,M=0$")
ax1.plot(x,gamI_ze_t11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,I,zE}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_ze_p00,label="$L=0,M=0$")
ax2.plot(x,gamI_ze_p10,label="$L=1,M=0$")
ax2.plot(x,gamI_ze_p11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,I,zE}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,V,zE}_{LM,\alpha}$

# %%
gamV_ze_t00 = f.Gamma_V_zE(0,0,x,lmax,0)
gamV_ze_t10 = f.Gamma_V_zE(1,0,x,lmax,0)
gamV_ze_t11 = f.Gamma_V_zE(1,1,x,lmax,0)

# %%
gamV_ze_p00 = f.Gamma_V_zE(0,0,x,lmax,1)
gamV_ze_p10 = f.Gamma_V_zE(1,0,x,lmax,1)
gamV_ze_p11 = f.Gamma_V_zE(1,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_ze_t00,label="$L=0,M=0$")
ax1.plot(x,gamV_ze_t10,label="$L=1,M=0$")
ax1.plot(x,gamV_ze_t11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,V,zE}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_ze_p00,label="$L=0,M=0$")
ax2.plot(x,gamV_ze_p10,label="$L=1,M=0$")
ax2.plot(x,gamV_ze_p11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,V,zE}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,E,zE}_{LM,\alpha}$

# %%
gamE_ze_t40 = f.Gamma_E_zE(4,0,x,lmax,0)
gamE_ze_t41 = f.Gamma_E_zE(4,1,x,lmax,0)

# %%
gamE_ze_p40 = f.Gamma_E_zE(4,0,x,lmax,1)
gamE_ze_p41 = f.Gamma_E_zE(4,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_ze_t40,label="$L=4,M=0$")
ax1.plot(x,gamE_ze_t41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,E,zE}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_ze_p40,label="$L=4,M=0$")
ax2.plot(x,gamE_ze_p41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,E,zE}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,B,zE}_{LM,\alpha}$

# %%
gamB_ze_t40 = f.Gamma_B_zE(4,0,x,lmax,0)
gamB_ze_t41 = f.Gamma_B_zE(4,1,x,lmax,0)

# %%
gamB_ze_p40 = f.Gamma_B_zE(4,0,x,lmax,1)
gamB_ze_p41 = f.Gamma_B_zE(4,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_ze_t40,label="$L=4,M=0$")
ax1.plot(x,gamB_ze_t41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,B,zE}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_ze_p40,label="$L=4,M=0$")
ax2.plot(x,gamB_ze_p41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,B,zE}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# ### $\Gamma^{t,X,Bz}_{LM,\alpha}$

# %% [markdown]
# #### $\Gamma^{t,I,Bz}_{LM,\alpha}$

# %%
gamI_bz_t00 = f.Gamma_I_Bz(0,0,x,lmax,0)
gamI_bz_t10 = f.Gamma_I_Bz(1,0,x,lmax,0)
gamI_bz_t11 = f.Gamma_I_Bz(1,1,x,lmax,0)

# %%
gamI_bz_p00 = f.Gamma_I_Bz(0,0,x,lmax,1)
gamI_bz_p10 = f.Gamma_I_Bz(1,0,x,lmax,1)
gamI_bz_p11 = f.Gamma_I_Bz(1,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_bz_t00,label="$L=0,M=0$")
ax1.plot(x,gamI_bz_t10,label="$L=1,M=0$")
ax1.plot(x,gamI_bz_t11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,I,Bz}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_bz_p00,label="$L=0,M=0$")
ax2.plot(x,gamI_bz_p10,label="$L=1,M=0$")
ax2.plot(x,gamI_bz_p11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,I,Bz}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,V,Bz}_{LM,\alpha}$

# %%
gamV_bz_t00 = f.Gamma_V_Bz(0,0,x,lmax,0)
gamV_bz_t10 = f.Gamma_V_Bz(1,0,x,lmax,0)
gamV_bz_t11 = f.Gamma_V_Bz(1,1,x,lmax,0)

# %%
gamV_bz_p00 = f.Gamma_V_Bz(0,0,x,lmax,1)
gamV_bz_p10 = f.Gamma_V_Bz(1,0,x,lmax,1)
gamV_bz_p11 = f.Gamma_V_Bz(1,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_bz_t00,label="$L=0,M=0$")
ax1.plot(x,gamV_bz_t10,label="$L=1,M=0$")
ax1.plot(x,gamV_bz_t11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,V,Bz}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_bz_p00,label="$L=0,M=0$")
ax2.plot(x,gamV_bz_p10,label="$L=1,M=0$")
ax2.plot(x,gamV_bz_p11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,V,Bz}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,E,Bz}_{LM,\alpha}$

# %%
gamE_bz_t40 = f.Gamma_E_Bz(4,0,x,lmax,0)
gamE_bz_t41 = f.Gamma_E_Bz(4,1,x,lmax,0)

# %%
gamE_bz_p40 = f.Gamma_E_Bz(4,0,x,lmax,1)
gamE_bz_p41 = f.Gamma_E_Bz(4,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_bz_t40,label="$L=4,M=0$")
ax1.plot(x,gamE_bz_t41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,E,Bz}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_bz_p40,label="$L=4,M=0$")
ax2.plot(x,gamE_bz_p41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,E,Bz}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,B,Bz}_{LM,\alpha}$

# %%
gamB_bz_t40 = f.Gamma_B_Bz(4,0,x,lmax,0)
gamB_bz_t41 = f.Gamma_B_Bz(4,1,x,lmax,0)

# %%
gamB_bz_p40 = f.Gamma_B_Bz(4,0,x,lmax,1)
gamB_bz_p41 = f.Gamma_B_Bz(4,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_bz_t40,label="$L=4,M=0$")
ax1.plot(x,gamB_bz_t41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,B,Bz}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_bz_p40,label="$L=4,M=0$")
ax2.plot(x,gamB_bz_p41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,B,Bz}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# ### $\Gamma^{t,X,zB}_{LM,\alpha}$

# %% [markdown]
# #### $\Gamma^{t,I,zB}_{LM,\alpha}$

# %%
gamI_zb_t00 = f.Gamma_I_zB(0,0,x,lmax,0)
gamI_zb_t10 = f.Gamma_I_zB(1,0,x,lmax,0)
gamI_zb_t11 = f.Gamma_I_zB(1,1,x,lmax,0)

# %%
gamI_zb_p00 = f.Gamma_I_zB(0,0,x,lmax,1)
gamI_zb_p10 = f.Gamma_I_zB(1,0,x,lmax,1)
gamI_zb_p11 = f.Gamma_I_zB(1,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_zb_t00,label="$L=0,M=0$")
ax1.plot(x,gamI_zb_t10,label="$L=1,M=0$")
ax1.plot(x,gamI_zb_t11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,I,zB}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_zb_p00,label="$L=0,M=0$")
ax2.plot(x,gamI_zb_p10,label="$L=1,M=0$")
ax2.plot(x,gamI_zb_p11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,I,zB}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,V,zB}_{LM,\alpha}$

# %%
gamV_zb_t00 = f.Gamma_V_zB(0,0,x,lmax,0)
gamV_zb_t10 = f.Gamma_V_zB(1,0,x,lmax,0)
gamV_zb_t11 = f.Gamma_V_zB(1,1,x,lmax,0)

# %%
gamV_zb_p00 = f.Gamma_V_zB(0,0,x,lmax,1)
gamV_zb_p10 = f.Gamma_V_zB(1,0,x,lmax,1)
gamV_zb_p11 = f.Gamma_V_zB(1,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_zb_t00,label="$L=0,M=0$")
ax1.plot(x,gamV_zb_t10,label="$L=1,M=0$")
ax1.plot(x,gamV_zb_t11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,V,zB}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_zb_p00,label="$L=0,M=0$")
ax2.plot(x,gamV_zb_p10,label="$L=1,M=0$")
ax2.plot(x,gamV_zb_p11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,V,zB}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,E,zB}_{LM,\alpha}$

# %%
gamE_zb_t40 = f.Gamma_E_zB(4,0,x,lmax,0)
gamE_zb_t41 = f.Gamma_E_zB(4,1,x,lmax,0)

# %%
gamE_zb_p40 = f.Gamma_E_zB(4,0,x,lmax,1)
gamE_zb_p41 = f.Gamma_E_zB(4,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_zb_t40,label="$L=4,M=0$")
ax1.plot(x,gamE_zb_t41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,E,zB}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_zb_p40,label="$L=4,M=0$")
ax2.plot(x,gamE_zb_p41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,E,zB}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{t,B,zB}_{LM,\alpha}$

# %%
gamB_zb_t40 = f.Gamma_B_zB(4,0,x,lmax,0)
gamB_zb_t41 = f.Gamma_B_zB(4,1,x,lmax,0)

# %%
gamB_zb_p40 = f.Gamma_B_zB(4,0,x,lmax,1)
gamB_zb_p41 = f.Gamma_B_zB(4,1,x,lmax,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_zb_t40,label="$L=4,M=0$")
ax1.plot(x,gamB_zb_t41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,B,zB}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_zb_p40,label="$L=4,M=0$")
ax2.plot(x,gamB_zb_p41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,B,zB}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# ## $\Gamma^{v,X,Sz}_{LM,\alpha}$ and $\Gamma^{v,X,zS}_{LM,\alpha}$ (spin-1 GWs)

# %% [markdown]
# ### $\Gamma^{v,X,Ez}_{LM,\alpha}$

# %%
lmax3 = 20

# %% [markdown]
# #### $\Gamma^{v,I,Ez}_{LM,\alpha}$

# %%
gamI_ez_t00_v = f.Gamma_I_Ez_v(0,0,x,lmax3,0)
gamI_ez_t10_v = f.Gamma_I_Ez_v(1,0,x,lmax3,0)
gamI_ez_t11_v = f.Gamma_I_Ez_v(1,1,x,lmax3,0)

# %%
gamI_ez_p00_v = f.Gamma_I_Ez_v(0,0,x,lmax3,1)
gamI_ez_p10_v = f.Gamma_I_Ez_v(1,0,x,lmax3,1)
gamI_ez_p11_v = f.Gamma_I_Ez_v(1,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_ez_t00_v,label="$L=0,M=0$")
ax1.plot(x,gamI_ez_t10_v,label="$L=1,M=0$")
ax1.plot(x,gamI_ez_t11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,I,Ez}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_ez_p00_v,label="$L=0,M=0$")
ax2.plot(x,gamI_ez_p10_v,label="$L=1,M=0$")
ax2.plot(x,gamI_ez_p11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,I,Ez}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


#fig.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_v_I_ez_2.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,V,Ez}_{LM,\alpha}$

# %%
gamV_ez_t00_v = f.Gamma_V_Ez_v(0,0,x,lmax3,0)
gamV_ez_t10_v = f.Gamma_V_Ez_v(1,0,x,lmax3,0)
gamV_ez_t11_v = f.Gamma_V_Ez_v(1,1,x,lmax3,0)

# %%
gamV_ez_p00_v = f.Gamma_V_Ez_v(0,0,x,lmax3,1)
gamV_ez_p10_v = f.Gamma_V_Ez_v(1,0,x,lmax3,1)
gamV_ez_p11_v = f.Gamma_V_Ez_v(1,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_ez_t00_v,label="$L=0,M=0$")
ax1.plot(x,gamV_ez_t10_v,label="$L=1,M=0$")
ax1.plot(x,gamV_ez_t11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,V,Ez}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_ez_p00_v,label="$L=0,M=0$")
ax2.plot(x,gamV_ez_p10_v,label="$L=1,M=0$")
ax2.plot(x,gamV_ez_p11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,V,Ez}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,E,Ez}_{LM,\alpha}$

# %%
gamE_ez_t20_v = f.Gamma_E_Ez_v(2,0,x,lmax3,0)
gamE_ez_t21_v = f.Gamma_E_Ez_v(2,1,x,lmax3,0)

# %%
gamE_ez_p20_v = f.Gamma_E_Ez_v(2,0,x,lmax3,1)
gamE_ez_p21_v = f.Gamma_E_Ez_v(2,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_ez_t20_v,label="$L=2,M=0$")
ax1.plot(x,gamE_ez_t21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,E,Ez}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_ez_p20_v,label="$L=2,M=0$")
ax2.plot(x,gamE_ez_p21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,E,Ez}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,B,Ez}_{LM,\alpha}$

# %%
gamB_ez_t20_v = f.Gamma_B_Ez_v(2,0,x,lmax3,0)
gamB_ez_t21_v = f.Gamma_B_Ez_v(2,1,x,lmax3,0)

# %%
gamB_ez_p20_v = f.Gamma_B_Ez_v(2,0,x,lmax3,1)
gamB_ez_p21_v = f.Gamma_B_Ez_v(2,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_ez_t20_v,label="$L=2,M=0$")
ax1.plot(x,gamB_ez_t21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,B,Ez}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_ez_p20_v,label="$L=2,M=0$")
ax2.plot(x,gamB_ez_p21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,B,Ez}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# ### $\Gamma^{v,X,zE}_{LM,\alpha}$

# %% [markdown]
# #### $\Gamma^{v,I,zE}_{LM,\alpha}$

# %%
gamI_ze_t00_v = f.Gamma_I_zE_v(0,0,x,lmax3,0)
gamI_ze_t10_v = f.Gamma_I_zE_v(1,0,x,lmax3,0)
gamI_ze_t11_v = f.Gamma_I_zE_v(1,1,x,lmax3,0)

# %%
gamI_ze_p00_v = f.Gamma_I_zE_v(0,0,x,lmax3,1)
gamI_ze_p10_v = f.Gamma_I_zE_v(1,0,x,lmax3,1)
gamI_ze_p11_v = f.Gamma_I_zE_v(1,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_ze_t00_v,label="$L=0,M=0$")
ax1.plot(x,gamI_ze_t10_v,label="$L=1,M=0$")
ax1.plot(x,gamI_ze_t11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,I,zE}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_ze_p00_v,label="$L=0,M=0$")
ax2.plot(x,gamI_ze_p10_v,label="$L=1,M=0$")
ax2.plot(x,gamI_ze_p11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,I,zE}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,V,zE}_{LM,\alpha}$

# %%
gamV_ze_t00_v = f.Gamma_V_zE_v(0,0,x,lmax3,0)
gamV_ze_t10_v = f.Gamma_V_zE_v(1,0,x,lmax3,0)
gamV_ze_t11_v = f.Gamma_V_zE_v(1,1,x,lmax3,0)

# %%
gamV_ze_p00_v = f.Gamma_V_zE_v(0,0,x,lmax3,1)
gamV_ze_p10_v = f.Gamma_V_zE_v(1,0,x,lmax3,1)
gamV_ze_p11_v = f.Gamma_V_zE_v(1,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_ze_t00_v,label="$L=0,M=0$")
ax1.plot(x,gamV_ze_t10_v,label="$L=1,M=0$")
ax1.plot(x,gamV_ze_t11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,V,zE}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_ze_p00_v,label="$L=0,M=0$")
ax2.plot(x,gamV_ze_p10_v,label="$L=1,M=0$")
ax2.plot(x,gamV_ze_p11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,V,zE}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,E,zE}_{LM,\alpha}$

# %%
gamE_ze_t20_v = f.Gamma_E_zE_v(2,0,x,lmax3,0)
gamE_ze_t21_v = f.Gamma_E_zE_v(2,1,x,lmax3,0)

# %%
gamE_ze_p20_v = f.Gamma_E_zE_v(2,0,x,lmax3,1)
gamE_ze_p21_v = f.Gamma_E_zE_v(2,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_ze_t20_v,label="$L=2,M=0$")
ax1.plot(x,gamE_ze_t21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,E,zE}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_ze_p20_v,label="$L=2,M=0$")
ax2.plot(x,gamE_ze_p21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,E,zE}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,B,zE}_{LM,\alpha}$

# %%
gamB_ze_t20_v = f.Gamma_B_zE_v(2,0,x,lmax3,0)
gamB_ze_t21_v = f.Gamma_B_zE_v(2,1,x,lmax3,0)

# %%
gamB_ze_p20_v = f.Gamma_B_zE_v(2,0,x,lmax3,1)
gamB_ze_p21_v = f.Gamma_B_zE_v(2,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_ze_t20_v,label="$L=2,M=0$")
ax1.plot(x,gamB_ze_t21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,B,zE}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_ze_p20_v,label="$L=2,M=0$")
ax2.plot(x,gamB_ze_p21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,B,zE}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# ### $\Gamma^{v,X,Bz}_{LM,\alpha}$

# %% [markdown]
# #### $\Gamma^{v,I,Bz}_{LM,\alpha}$

# %%
gamI_bz_t00_v = f.Gamma_I_Bz_v(0,0,x,lmax3,0)
gamI_bz_t10_v = f.Gamma_I_Bz_v(1,0,x,lmax3,0)
gamI_bz_t11_v = f.Gamma_I_Bz_v(1,1,x,lmax3,0)

# %%
gamI_bz_p00_v = f.Gamma_I_Bz_v(0,0,x,lmax3,1)
gamI_bz_p10_v = f.Gamma_I_Bz_v(1,0,x,lmax3,1)
gamI_bz_p11_v = f.Gamma_I_Bz_v(1,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_bz_t00_v,label="$L=0,M=0$")
ax1.plot(x,gamI_bz_t10_v,label="$L=1,M=0$")
ax1.plot(x,gamI_bz_t11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,I,Bz}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_bz_p00_v,label="$L=0,M=0$")
ax2.plot(x,gamI_bz_p10_v,label="$L=1,M=0$")
ax2.plot(x,gamI_bz_p11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,I,Bz}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,V,Bz}_{LM,\alpha}$

# %%
gamV_bz_t00_v = f.Gamma_V_Bz_v(0,0,x,lmax3,0)
gamV_bz_t10_v = f.Gamma_V_Bz_v(1,0,x,lmax3,0)
gamV_bz_t11_v = f.Gamma_V_Bz_v(1,1,x,lmax3,0)

# %%
gamV_bz_p00_v = f.Gamma_V_Bz_v(0,0,x,lmax3,1)
gamV_bz_p10_v = f.Gamma_V_Bz_v(1,0,x,lmax3,1)
gamV_bz_p11_v = f.Gamma_V_Bz_v(1,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_bz_t00_v,label="$L=0,M=0$")
ax1.plot(x,gamV_bz_t10_v,label="$L=1,M=0$")
ax1.plot(x,gamV_bz_t11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,V,Bz}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_bz_p00_v,label="$L=0,M=0$")
ax2.plot(x,gamV_bz_p10_v,label="$L=1,M=0$")
ax2.plot(x,gamV_bz_p11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,V,Bz}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,E,Bz}_{LM,\alpha}$

# %%
gamE_bz_t20_v = f.Gamma_E_Bz_v(2,0,x,lmax3,0)
gamE_bz_t21_v = f.Gamma_E_Bz_v(2,1,x,lmax3,0)

# %%
gamE_bz_p20_v = f.Gamma_E_Bz_v(2,0,x,lmax3,1)
gamE_bz_p21_v = f.Gamma_E_Bz_v(2,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_bz_t20_v,label="$L=2,M=0$")
ax1.plot(x,gamE_bz_t21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,E,Bz}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_bz_p20_v,label="$L=2,M=0$")
ax2.plot(x,gamE_bz_p21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,E,Bz}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,B,Bz}_{LM,\alpha}$

# %%
gamB_bz_t20_v = f.Gamma_B_Bz_v(2,0,x,lmax3,0)
gamB_bz_t21_v = f.Gamma_B_Bz_v(2,1,x,lmax3,0)

# %%
gamB_bz_p20_v = f.Gamma_B_Bz_v(2,0,x,lmax3,1)
gamB_bz_p21_v = f.Gamma_B_Bz_v(2,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_bz_t20_v,label="$L=2,M=0$")
ax1.plot(x,gamB_bz_t21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,B,Bz}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_bz_p20_v,label="$L=2,M=0$")
ax2.plot(x,gamB_bz_p21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,B,Bz}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# ### $\Gamma^{v,X,zB}_{LM,\alpha}$

# %% [markdown]
# #### $\Gamma^{v,I,zB}_{LM,\alpha}$

# %%
gamI_zb_t00_v = f.Gamma_I_zB_v(0,0,x,lmax3,0)
gamI_zb_t10_v = f.Gamma_I_zB_v(1,0,x,lmax3,0)
gamI_zb_t11_v = f.Gamma_I_zB_v(1,1,x,lmax3,0)

# %%
gamI_zb_p00_v = f.Gamma_I_zB_v(0,0,x,lmax3,1)
gamI_zb_p10_v = f.Gamma_I_zB_v(1,0,x,lmax3,1)
gamI_zb_p11_v = f.Gamma_I_zB_v(1,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_zb_t00_v,label="$L=0,M=0$")
ax1.plot(x,gamI_zb_t10_v,label="$L=1,M=0$")
ax1.plot(x,gamI_zb_t11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,I,zB}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_zb_p00_v,label="$L=0,M=0$")
ax2.plot(x,gamI_zb_p10_v,label="$L=1,M=0$")
ax2.plot(x,gamI_zb_p11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,I,zB}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,V,zB}_{LM,\alpha}$

# %%
gamV_zb_t00_v = f.Gamma_V_zB_v(0,0,x,lmax3,0)
gamV_zb_t10_v = f.Gamma_V_zB_v(1,0,x,lmax3,0)
gamV_zb_t11_v = f.Gamma_V_zB_v(1,1,x,lmax3,0)

# %%
gamV_zb_p00_v = f.Gamma_V_zB_v(0,0,x,lmax3,1)
gamV_zb_p10_v = f.Gamma_V_zB_v(1,0,x,lmax3,1)
gamV_zb_p11_v = f.Gamma_V_zB_v(1,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_zb_t00_v,label="$L=0,M=0$")
ax1.plot(x,gamV_zb_t10_v,label="$L=1,M=0$")
ax1.plot(x,gamV_zb_t11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,V,zB}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_zb_p00_v,label="$L=0,M=0$")
ax2.plot(x,gamV_zb_p10_v,label="$L=1,M=0$")
ax2.plot(x,gamV_zb_p11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,V,zB}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,E,zB}_{LM,\alpha}$

# %%
gamE_zb_t20_v = f.Gamma_E_zB_v(2,0,x,lmax3,0)
gamE_zb_t21_v = f.Gamma_E_zB_v(2,1,x,lmax3,0)

# %%
gamE_zb_p20_v = f.Gamma_E_zB_v(2,0,x,lmax3,1)
gamE_zb_p21_v = f.Gamma_E_zB_v(2,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_zb_t20_v,label="$L=2,M=0$")
ax1.plot(x,gamE_zb_t21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,E,zB}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_zb_p20_v,label="$L=2,M=0$")
ax2.plot(x,gamE_zb_p21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,E,zB}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()

# %% [markdown]
# #### $\Gamma^{v,B,zB}_{LM,\alpha}$

# %%
gamB_zb_t20_v = f.Gamma_B_zB_v(2,0,x,lmax3,0)
gamB_zb_t21_v = f.Gamma_B_zB_v(2,1,x,lmax3,0)

# %%
gamB_zb_p20_v = f.Gamma_B_zB_v(2,0,x,lmax3,1)
gamB_zb_p21_v = f.Gamma_B_zB_v(2,1,x,lmax3,1)

# %%
fig = plt.figure(figsize = (12,4),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_zb_t20_v,label="$L=2,M=0$")
ax1.plot(x,gamB_zb_t21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,B,zB}_{LM,\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_zb_p20_v,label="$L=2,M=0$")
ax2.plot(x,gamB_zb_p21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,B,zB}_{LM,\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')


plt.show()
