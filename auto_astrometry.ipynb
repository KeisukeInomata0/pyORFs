# %% [markdown]
# # $\Gamma^{p,X,ST}_{LM,\alpha\beta}$ in $p \in \{t,v\}$, $X \in \{I,V,E,B\}$, $S,T \in \{E,B\}$, and $\alpha,\beta \in \{\theta, \phi\}$

# %% [markdown]
# ### Keisuke Inomata

# %%
# %matplotlib inline

# Import standard packages
import numpy as np
import matplotlib.pyplot as plt

# Import module for the functions
import functions as f
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# settings for plots
plt.rcParams['font.family'] = 'Times New Roman' # font family
plt.rcParams['mathtext.fontset'] = 'stix' # math font
plt.rcParams["font.size"] = 15 # fontsize
plt.rcParams['xtick.labelsize'] = 15 # 
plt.rcParams['ytick.labelsize'] = 15 # 

plt.rcParams['xtick.direction'] = 'in' # x axis in
plt.rcParams['ytick.direction'] = 'in' # y axis in 
plt.rcParams['axes.linewidth'] = 1.0 # axis line width
plt.rcParams['axes.grid'] = True # make grid

# %% [markdown]
# ### determine the number of plot points and lmax

# %%
div = 50 # number of points between [0, Pi]
lmax = 10 # max value of l which we take into account
epsilon = 1e-4 # regulator
x = np.arange(epsilon, np.pi-epsilon, np.pi/div)

# %% [markdown]
# ## $\Gamma^{t,X,ST}_{LM,\alpha\beta}$ (spin-2 GWs)

# %% [markdown]
# ### $\Gamma^{t,X,EE}_{LM,\alpha\beta}$

# %% [markdown]
# #### $\Gamma^{t,I,EE}_{LM,\alpha\beta}$

# %%
gamI_ee_tt00 = f.Gamma_I_EE(0,0,x,lmax,0,0)
gamI_ee_tt10 = f.Gamma_I_EE(1,0,x,lmax,0,0)
gamI_ee_tt11 = f.Gamma_I_EE(1,1,x,lmax,0,0)

# %%
gamI_ee_tp00 = f.Gamma_I_EE(0,0,x,lmax,0,1)
gamI_ee_tp10 = f.Gamma_I_EE(1,0,x,lmax,0,1)
gamI_ee_tp11 = f.Gamma_I_EE(1,1,x,lmax,0,1)

# %%
gamI_ee_pt00 = f.Gamma_I_EE(0,0,x,lmax,1,0)
gamI_ee_pt10 = f.Gamma_I_EE(1,0,x,lmax,1,0)
gamI_ee_pt11 = f.Gamma_I_EE(1,1,x,lmax,1,0)

# %%
gamI_ee_pp00 = f.Gamma_I_EE(0,0,x,lmax,1,1)
gamI_ee_pp10 = f.Gamma_I_EE(1,0,x,lmax,1,1)
gamI_ee_pp11 = f.Gamma_I_EE(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_ee_tt00,label="$L=0,M=0$")
ax1.plot(x,gamI_ee_tt10,label="$L=1,M=0$")
ax1.plot(x,gamI_ee_tt11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,I,EE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_ee_tp00,label="$L=0,M=0$")
ax2.plot(x,gamI_ee_tp10,label="$L=1,M=0$")
ax2.plot(x,gamI_ee_tp11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,I,EE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamI_ee_pt00,label="$L=0,M=0$")
ax3.plot(x,gamI_ee_pt10,label="$L=1,M=0$")
ax3.plot(x,gamI_ee_pt11,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{t,I,EE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamI_ee_pp00,label="$L=0,M=0$")
ax4.plot(x,gamI_ee_pp10,label="$L=1,M=0$")
ax4.plot(x,gamI_ee_pp11,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{t,I,EE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{t,V,EE}_{LM,\alpha\beta}$

# %%
gamV_ee_tt00 = f.Gamma_V_EE(0,0,x,lmax,0,0)
gamV_ee_tt10 = f.Gamma_V_EE(1,0,x,lmax,0,0)
gamV_ee_tt11 = f.Gamma_V_EE(1,1,x,lmax,0,0)

# %%
gamV_ee_tp00 = f.Gamma_V_EE(0,0,x,lmax,0,1)
gamV_ee_tp10 = f.Gamma_V_EE(1,0,x,lmax,0,1)
gamV_ee_tp11 = f.Gamma_V_EE(1,1,x,lmax,0,1)

# %%
gamV_ee_pt00 = f.Gamma_V_EE(0,0,x,lmax,1,0)
gamV_ee_pt10 = f.Gamma_V_EE(1,0,x,lmax,1,0)
gamV_ee_pt11 = f.Gamma_V_EE(1,1,x,lmax,1,0)

# %%
gamV_ee_pp00 = f.Gamma_V_EE(0,0,x,lmax,1,1)
gamV_ee_pp10 = f.Gamma_V_EE(1,0,x,lmax,1,1)
gamV_ee_pp11 = f.Gamma_V_EE(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_ee_tt00,label="$L=0,M=0$")
ax1.plot(x,gamV_ee_tt10,label="$L=1,M=0$")
ax1.plot(x,gamV_ee_tt11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,V,EE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_ee_tp00,label="$L=0,M=0$")
ax2.plot(x,gamV_ee_tp10,label="$L=1,M=0$")
ax2.plot(x,gamV_ee_tp11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,V,EE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamV_ee_pt00,label="$L=0,M=0$")
ax3.plot(x,gamV_ee_pt10,label="$L=1,M=0$")
ax3.plot(x,gamV_ee_pt11,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{t,V,EE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamV_ee_pp00,label="$L=0,M=0$")
ax4.plot(x,gamV_ee_pp10,label="$L=1,M=0$")
ax4.plot(x,gamV_ee_pp11,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{t,V,EE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{t,E,EE}_{LM,\alpha\beta}$

# %%
gamE_ee_tt40 = f.Gamma_E_EE(4,0,x,lmax,0,0)
gamE_ee_tt41 = f.Gamma_E_EE(4,1,x,lmax,0,0)

# %%
gamE_ee_tp40 = f.Gamma_E_EE(4,0,x,lmax,0,1)
gamE_ee_tp41 = f.Gamma_E_EE(4,1,x,lmax,0,1)

# %%
gamE_ee_pt40 = f.Gamma_E_EE(4,0,x,lmax,1,0)
gamE_ee_pt41 = f.Gamma_E_EE(4,1,x,lmax,1,0)

# %%
gamE_ee_pp40 = f.Gamma_E_EE(4,0,x,lmax,1,1)
gamE_ee_pp41 = f.Gamma_E_EE(4,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_ee_tt40,label="$L=4,M=0$")
ax1.plot(x,gamE_ee_tt41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,E,EE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_ee_tp40,label="$L=4,M=0$")
ax2.plot(x,gamE_ee_tp41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,E,EE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamE_ee_pt40,label="$L=4,M=0$")
ax3.plot(x,gamE_ee_pt41,label="$L=4,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{t,E,EE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamE_ee_pp40,label="$L=4,M=0$")
ax4.plot(x,gamE_ee_pp41,label="$L=4,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{t,E,EE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{t,B,EE}_{LM,\alpha\beta}$

# %%
gamB_ee_tt40 = f.Gamma_B_EE(4,0,x,lmax,0,0)
gamB_ee_tt41 = f.Gamma_B_EE(4,1,x,lmax,0,0)

# %%
gamB_ee_tp40 = f.Gamma_B_EE(4,0,x,lmax,0,1)
gamB_ee_tp41 = f.Gamma_B_EE(4,1,x,lmax,0,0)

# %%
gamB_ee_pt40 = f.Gamma_B_EE(4,0,x,lmax,1,0)
gamB_ee_pt41 = f.Gamma_B_EE(4,1,x,lmax,1,0)

# %%
gamB_ee_pp40 = f.Gamma_B_EE(4,0,x,lmax,1,1)
gamB_ee_pp41 = f.Gamma_B_EE(4,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_ee_tt40,label="$L=4,M=0$")
ax1.plot(x,gamB_ee_tt41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{t,B,EE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_ee_tp40,label="$L=4,M=0$")
ax2.plot(x,gamB_ee_tp41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,B,EE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamB_ee_pt40,label="$L=4,M=0$")
ax3.plot(x,gamB_ee_pt41,label="$L=4,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{t,B,EE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamB_ee_pp40,label="$L=4,M=0$")
ax4.plot(x,gamB_ee_pp41,label="$L=4,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{t,B,EE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# ### $\Gamma^{t,X,EB}_{LM,\alpha\beta}$

# %% [markdown]
# #### $\Gamma^{t,I,EB}_{LM,\alpha\beta}$

# %%
gamI_eb_tt00 = f.Gamma_I_EB(0,0,x,lmax,0,0)
gamI_eb_tt10 = f.Gamma_I_EB(1,0,x,lmax,0,0)
gamI_eb_tt11 = f.Gamma_I_EB(1,1,x,lmax,0,0)

# %%
gamI_eb_tp00 = f.Gamma_I_EB(0,0,x,lmax,0,1)
gamI_eb_tp10 = f.Gamma_I_EB(1,0,x,lmax,0,1)
gamI_eb_tp11 = f.Gamma_I_EB(1,1,x,lmax,0,1)

# %%
gamI_eb_pt00 = f.Gamma_I_EB(0,0,x,lmax,1,0)
gamI_eb_pt10 = f.Gamma_I_EB(1,0,x,lmax,1,0)
gamI_eb_pt11 = f.Gamma_I_EB(1,1,x,lmax,1,0)

# %%
gamI_eb_pp00 = f.Gamma_I_EB(0,0,x,lmax,1,1)
gamI_eb_pp10 = f.Gamma_I_EB(1,0,x,lmax,1,1)
gamI_eb_pp11 = f.Gamma_I_EB(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_eb_tt00,label="$L=0,M=0$")
ax1.plot(x,gamI_eb_tt10,label="$L=1,M=0$")
ax1.plot(x,gamI_eb_tt11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,I,EB}_{LM,\\theta\\theta}$")

fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_eb_tp00,label="$L=0,M=0$")
ax2.plot(x,gamI_eb_tp10,label="$L=1,M=0$")
ax2.plot(x,gamI_eb_tp11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,I,EB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamI_eb_pt00,label="$L=0,M=0$")
ax3.plot(x,gamI_eb_pt10,label="$L=1,M=0$")
ax3.plot(x,gamI_eb_pt11,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$i\,\Gamma^{t,I,EB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamI_eb_pp00,label="$L=0,M=0$")
ax4.plot(x,gamI_eb_pp10,label="$L=1,M=0$")
ax4.plot(x,gamI_eb_pp11,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{t,I,EB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

#fig.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_t_I_eb_2.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### $\Gamma^{t,V,EB}_{LM,\alpha\beta}$

# %%
gamV_eb_tt00 = f.Gamma_V_EB(0,0,x,lmax,0,0)
gamV_eb_tt10 = f.Gamma_V_EB(1,0,x,lmax,0,0)
gamV_eb_tt11 = f.Gamma_V_EB(1,1,x,lmax,0,0)

# %%
gamV_eb_tp00 = f.Gamma_V_EB(0,0,x,lmax,0,1)
gamV_eb_tp10 = f.Gamma_V_EB(1,0,x,lmax,0,1)
gamV_eb_tp11 = f.Gamma_V_EB(1,1,x,lmax,0,1)

# %%
gamV_eb_pt00 = f.Gamma_V_EB(0,0,x,lmax,1,0)
gamV_eb_pt10 = f.Gamma_V_EB(1,0,x,lmax,1,0)
gamV_eb_pt11 = f.Gamma_V_EB(1,1,x,lmax,1,0)

# %%
gamV_eb_pp00 = f.Gamma_V_EB(0,0,x,lmax,1,1)
gamV_eb_pp10 = f.Gamma_V_EB(1,0,x,lmax,1,1)
gamV_eb_pp11 = f.Gamma_V_EB(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_eb_tt00,label="$L=0,M=0$")
ax1.plot(x,gamV_eb_tt10,label="$L=1,M=0$")
ax1.plot(x,gamV_eb_tt11,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,V,EB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_eb_tp00,label="$L=0,M=0$")
ax2.plot(x,gamV_eb_tp10,label="$L=1,M=0$")
ax2.plot(x,gamV_eb_tp11,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,V,EB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamV_eb_pt00,label="$L=0,M=0$")
ax3.plot(x,gamV_eb_pt10,label="$L=1,M=0$")
ax3.plot(x,gamV_eb_pt11,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$i\,\Gamma^{t,V,EB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamV_eb_pp00,label="$L=0,M=0$")
ax4.plot(x,gamV_eb_pp10,label="$L=1,M=0$")
ax4.plot(x,gamV_eb_pp11,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{t,V,EB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{t,E,EB}_{LM,\alpha\beta}$

# %%
gamE_eb_tt40 = f.Gamma_E_EB(4,0,x,lmax,0,0)
gamE_eb_tt41 = f.Gamma_E_EB(4,1,x,lmax,0,0)

# %%
gamE_eb_tp40 = f.Gamma_E_EB(4,0,x,lmax,0,1)
gamE_eb_tp41 = f.Gamma_E_EB(4,1,x,lmax,0,1)

# %%
gamE_eb_pt40 = f.Gamma_E_EB(4,0,x,lmax,1,0)
gamE_eb_pt41 = f.Gamma_E_EB(4,1,x,lmax,1,0)

# %%
gamE_eb_pp40 = f.Gamma_E_EB(4,0,x,lmax,1,1)
gamE_eb_pp41 = f.Gamma_E_EB(4,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_eb_tt40,label="$L=4,M=0$")
ax1.plot(x,gamE_eb_tt41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,E,EB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_eb_tp40,label="$L=4,M=0$")
ax2.plot(x,gamE_eb_tp41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,E,EB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamE_eb_pt40,label="$L=4,M=0$")
ax3.plot(x,gamE_eb_pt41,label="$L=4,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$i\,\Gamma^{t,E,EB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamE_eb_pp40,label="$L=4,M=0$")
ax4.plot(x,gamE_eb_pp41,label="$L=4,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{t,E,EB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{t,B,EB}_{LM,\alpha\beta}$

# %%
gamB_eb_tt40 = f.Gamma_B_EB(4,0,x,lmax,0,0)
gamB_eb_tt41 = f.Gamma_B_EB(4,1,x,lmax,0,0)

# %%
gamB_eb_tp40 = f.Gamma_B_EB(4,0,x,lmax,0,1)
gamB_eb_tp41 = f.Gamma_B_EB(4,1,x,lmax,0,1)

# %%
gamB_eb_pt40 = f.Gamma_B_EB(4,0,x,lmax,1,0)
gamB_eb_pt41 = f.Gamma_B_EB(4,1,x,lmax,1,0)

# %%
gamB_eb_pp40 = f.Gamma_B_EB(4,0,x,lmax,1,1)
gamB_eb_pp41 = f.Gamma_B_EB(4,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_eb_tt40,label="$L=4,M=0$")
ax1.plot(x,gamB_eb_tt41,label="$L=4,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{t,B,EB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_eb_tp40,label="$L=4,M=0$")
ax2.plot(x,gamB_eb_tp41,label="$L=4,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{t,B,EB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamB_eb_pt40,label="$L=4,M=0$")
ax3.plot(x,gamB_eb_pt41,label="$L=4,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$i\,\Gamma^{t,B,EB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamB_eb_pp40,label="$L=4,M=0$")
ax4.plot(x,gamB_eb_pp41,label="$L=4,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{t,B,EB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# ### $\Gamma^{t,X,BE}_{LM,\alpha\beta}$ and $\Gamma^{t,X,BB}_{LM,\alpha\beta}$

# %% [markdown]
# From $E^t_l = (-i)B^t_l$, $Y^E_{\theta} = Y^B_{\phi}, Y^E_{\phi} = - Y^B_{\theta}$, and $F^{X,EE}=Z^X F^{X,BB}$ and $F^{X,EB}=-Z^X F^{X,BE}$ with $Z^X=1$ for $X\in\{I,V\}$ and $Z^X=-1$ for $X\in\{E,B\}$, we obtain
# $$
# \begin{align}
# \Gamma^{t,X,BE}_{\theta\theta} &= Z^X \Gamma^{t,X,EB}_{\phi\phi}, \\
# \Gamma^{t,X,BE}_{\theta\phi} &= -Z^X\Gamma^{t,X,EB}_{\phi\theta}, \\
# \Gamma^{t,X,BE}_{\phi\theta} &= -Z^X\Gamma^{t,X,EB}_{\theta\phi}, \\
# \Gamma^{t,X,BE}_{\phi\phi} &= Z^X\Gamma^{t,X,EB}_{\theta\theta},
# \end{align}
# $$
# $$
# \begin{align}
# \Gamma^{t,X,BB}_{\theta\theta} &= Z^X\Gamma^{t,X,EE}_{\phi\phi}, \\
# \Gamma^{t,X,BB}_{\theta\phi} &= -Z^X\Gamma^{t,X,EE}_{\phi\theta}, \\
# \Gamma^{t,X,BB}_{\phi\theta} &= -Z^X\Gamma^{t,X,EE}_{\theta\phi}, \\
# \Gamma^{t,X,BB}_{\phi\phi} &= Z^X\Gamma^{t,X,EE}_{\theta\theta}.
# \end{align}
# $$

# %% [markdown]
# ## $\Gamma^{v,X,ST}_{LM,\alpha\beta}$ (spin-1 GWs)

# %% [markdown]
# ### $\Gamma^{v,X,EE}_{LM,\alpha\beta}$

# %% [markdown]
# #### $\Gamma^{v,I,EE}_{LM,\alpha\beta}$

# %%
gamI_ee_tt00_v = f.Gamma_I_EE_v(0,0,x,lmax,0,0)
gamI_ee_tt10_v = f.Gamma_I_EE_v(1,0,x,lmax,0,0)
gamI_ee_tt11_v = f.Gamma_I_EE_v(1,1,x,lmax,0,0)

# %%
gamI_ee_tp00_v = f.Gamma_I_EE_v(0,0,x,lmax,0,1)
gamI_ee_tp10_v = f.Gamma_I_EE_v(1,0,x,lmax,0,1)
gamI_ee_tp11_v = f.Gamma_I_EE_v(1,1,x,lmax,0,1)

# %%
gamI_ee_pt00_v = f.Gamma_I_EE_v(0,0,x,lmax,1,0)
gamI_ee_pt10_v = f.Gamma_I_EE_v(1,0,x,lmax,1,0)
gamI_ee_pt11_v = f.Gamma_I_EE_v(1,1,x,lmax,1,0)

# %%
gamI_ee_pp00_v = f.Gamma_I_EE_v(0,0,x,lmax,1,1)
gamI_ee_pp10_v = f.Gamma_I_EE_v(1,0,x,lmax,1,1)
gamI_ee_pp11_v = f.Gamma_I_EE_v(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_ee_tt00_v,label="$L=0,M=0$")
ax1.plot(x,gamI_ee_tt10_v,label="$L=1,M=0$")
ax1.plot(x,gamI_ee_tt11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,I,EE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_ee_tp00_v,label="$L=0,M=0$")
ax2.plot(x,gamI_ee_tp10_v,label="$L=1,M=0$")
ax2.plot(x,gamI_ee_tp11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,I,EE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamI_ee_pt00_v,label="$L=0,M=0$")
ax3.plot(x,gamI_ee_pt10_v,label="$L=1,M=0$")
ax3.plot(x,gamI_ee_pt11_v,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,I,EE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamI_ee_pp00_v,label="$L=0,M=0$")
ax4.plot(x,gamI_ee_pp10_v,label="$L=1,M=0$")
ax4.plot(x,gamI_ee_pp11_v,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,I,EE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,V,EE}_{LM,\alpha\beta}$

# %%
gamV_ee_tt00_v = f.Gamma_V_EE_v(0,0,x,lmax,0,0)
gamV_ee_tt10_v = f.Gamma_V_EE_v(1,0,x,lmax,0,0)
gamV_ee_tt11_v = f.Gamma_V_EE_v(1,1,x,lmax,0,0)

# %%
gamV_ee_tp00_v = f.Gamma_V_EE_v(0,0,x,lmax,0,1)
gamV_ee_tp10_v = f.Gamma_V_EE_v(1,0,x,lmax,0,1)
gamV_ee_tp11_v = f.Gamma_V_EE_v(1,1,x,lmax,0,1)

# %%
gamV_ee_pt00_v = f.Gamma_V_EE_v(0,0,x,lmax,1,0)
gamV_ee_pt10_v = f.Gamma_V_EE_v(1,0,x,lmax,1,0)
gamV_ee_pt11_v = f.Gamma_V_EE_v(1,1,x,lmax,1,0)

# %%
gamV_ee_pp00_v = f.Gamma_V_EE_v(0,0,x,lmax,1,1)
gamV_ee_pp10_v = f.Gamma_V_EE_v(1,0,x,lmax,1,1)
gamV_ee_pp11_v = f.Gamma_V_EE_v(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_ee_tt00_v,label="$L=0,M=0$")
ax1.plot(x,gamV_ee_tt10_v,label="$L=1,M=0$")
ax1.plot(x,gamV_ee_tt11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,V,EE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_ee_tp00_v,label="$L=0,M=0$")
ax2.plot(x,gamV_ee_tp10_v,label="$L=1,M=0$")
ax2.plot(x,gamV_ee_tp11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,V,EE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamV_ee_pt00_v,label="$L=0,M=0$")
ax3.plot(x,gamV_ee_pt10_v,label="$L=1,M=0$")
ax3.plot(x,gamV_ee_pt11_v,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,V,EE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamV_ee_pp00_v,label="$L=0,M=0$")
ax4.plot(x,gamV_ee_pp10_v,label="$L=1,M=0$")
ax4.plot(x,gamV_ee_pp11_v,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,V,EE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,E,EE}_{LM,\alpha\beta}$

# %%
gamE_ee_tt20_v = f.Gamma_E_EE_v(2,0,x,lmax,0,0)
gamE_ee_tt21_v = f.Gamma_E_EE_v(2,1,x,lmax,0,0)

# %%
gamE_ee_tp20_v = f.Gamma_E_EE_v(2,0,x,lmax,0,1)
gamE_ee_tp21_v = f.Gamma_E_EE_v(2,1,x,lmax,0,1)

# %%
gamE_ee_pt20_v = f.Gamma_E_EE_v(2,0,x,lmax,1,0)
gamE_ee_pt21_v = f.Gamma_E_EE_v(2,1,x,lmax,1,0)

# %%
gamE_ee_pp20_v = f.Gamma_E_EE_v(2,0,x,lmax,1,1)
gamE_ee_pp21_v = f.Gamma_E_EE_v(2,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_ee_tt20_v,label="$L=2,M=0$")
ax1.plot(x,gamE_ee_tt21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,E,EE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_ee_tp20_v,label="$L=2,M=0$")
ax2.plot(x,gamE_ee_tp21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,E,EE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamE_ee_pt20_v,label="$L=2,M=0$")
ax3.plot(x,gamE_ee_pt21_v,label="$L=2,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,E,EE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamE_ee_pp20_v,label="$L=2,M=0$")
ax4.plot(x,gamE_ee_pp21_v,label="$L=2,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,E,EE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,B,EE}_{LM,\alpha\beta}$

# %%
gamB_ee_tt20_v = f.Gamma_B_EE_v(2,0,x,lmax,0,0)
gamB_ee_tt21_v = f.Gamma_B_EE_v(2,1,x,lmax,0,0)

# %%
gamB_ee_tp20_v = f.Gamma_B_EE_v(2,0,x,lmax,0,1)
gamB_ee_tp21_v = f.Gamma_B_EE_v(2,1,x,lmax,0,1)

# %%
gamB_ee_pt20_v = f.Gamma_B_EE_v(2,0,x,lmax,1,0)
gamB_ee_pt21_v = f.Gamma_B_EE_v(2,1,x,lmax,1,0)

# %%
gamB_ee_pp20_v = f.Gamma_B_EE_v(2,0,x,lmax,1,1)
gamB_ee_pp21_v = f.Gamma_B_EE_v(2,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_ee_tt20_v,label="$L=2,M=0$")
ax1.plot(x,gamB_ee_tt21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$\Gamma^{v,B,EE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_ee_tp20_v,label="$L=2,M=0$")
ax2.plot(x,gamB_ee_tp21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,B,EE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamB_ee_pt20_v,label="$L=2,M=0$")
ax3.plot(x,gamB_ee_pt21_v,label="$L=2,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,B,EE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamB_ee_pp20_v,label="$L=2,M=0$")
ax4.plot(x,gamB_ee_pp21_v,label="$L=2,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,B,EE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# ### $\Gamma^{v,X,BB}_{LM,\alpha\beta}$

# %% [markdown]
# #### $\Gamma^{v,I,BB}_{LM,\alpha\beta}$

# %%
gamI_bb_tt00_v = f.Gamma_I_BB_v(0,0,x,lmax,0,0)
gamI_bb_tt10_v = f.Gamma_I_BB_v(1,0,x,lmax,0,0)
gamI_bb_tt11_v = f.Gamma_I_BB_v(1,1,x,lmax,0,0)

# %%
gamI_bb_tp00_v = f.Gamma_I_BB_v(0,0,x,lmax,0,1)
gamI_bb_tp10_v = f.Gamma_I_BB_v(1,0,x,lmax,0,1)
gamI_bb_tp11_v = f.Gamma_I_BB_v(1,1,x,lmax,0,1)

# %%
gamI_bb_pt00_v = f.Gamma_I_BB_v(0,0,x,lmax,1,0)
gamI_bb_pt10_v = f.Gamma_I_BB_v(1,0,x,lmax,1,0)
gamI_bb_pt11_v = f.Gamma_I_BB_v(1,1,x,lmax,1,0)

# %%
gamI_bb_pp00_v = f.Gamma_I_BB_v(0,0,x,lmax,1,1)
gamI_bb_pp10_v = f.Gamma_I_BB_v(1,0,x,lmax,1,1)
gamI_bb_pp11_v = f.Gamma_I_BB_v(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_bb_tt00_v,label="$L=0,M=0$")
ax1.plot(x,gamI_bb_tt10_v,label="$L=1,M=0$")
ax1.plot(x,gamI_bb_tt11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,I,BB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_bb_tp00_v,label="$L=0,M=0$")
ax2.plot(x,gamI_bb_tp10_v,label="$L=1,M=0$")
ax2.plot(x,gamI_bb_tp11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,I,BB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamI_bb_pt00_v,label="$L=0,M=0$")
ax3.plot(x,gamI_bb_pt10_v,label="$L=1,M=0$")
ax3.plot(x,gamI_bb_pt11_v,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,I,BB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamI_bb_pp00_v,label="$L=0,M=0$")
ax4.plot(x,gamI_bb_pp10_v,label="$L=1,M=0$")
ax4.plot(x,gamI_bb_pp11_v,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$\Gamma^{v,I,BB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,V,BB}_{LM,\alpha\beta}$

# %%
gamV_bb_tt00_v = f.Gamma_V_BB_v(0,0,x,lmax,0,0)
gamV_bb_tt10_v = f.Gamma_V_BB_v(1,0,x,lmax,0,0)
gamV_bb_tt11_v = f.Gamma_V_BB_v(1,1,x,lmax,0,0)

# %%
gamV_bb_tp00_v = f.Gamma_V_BB_v(0,0,x,lmax,0,1)
gamV_bb_tp10_v = f.Gamma_V_BB_v(1,0,x,lmax,0,1)
gamV_bb_tp11_v = f.Gamma_V_BB_v(1,1,x,lmax,0,1)

# %%
gamV_bb_pt00_v = f.Gamma_V_BB_v(0,0,x,lmax,1,0)
gamV_bb_pt10_v = f.Gamma_V_BB_v(1,0,x,lmax,1,0)
gamV_bb_pt11_v = f.Gamma_V_BB_v(1,1,x,lmax,1,0)

# %%
gamV_bb_pp00_v = f.Gamma_V_BB_v(0,0,x,lmax,1,1)
gamV_bb_pp10_v = f.Gamma_V_BB_v(1,0,x,lmax,1,1)
gamV_bb_pp11_v = f.Gamma_V_BB_v(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_bb_tt00_v,label="$L=0,M=0$")
ax1.plot(x,gamV_bb_tt10_v,label="$L=1,M=0$")
ax1.plot(x,gamV_bb_tt11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,V,BB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_bb_tp00_v,label="$L=0,M=0$")
ax2.plot(x,gamV_bb_tp10_v,label="$L=1,M=0$")
ax2.plot(x,gamV_bb_tp11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,V,BB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamV_bb_pt00_v,label="$L=0,M=0$")
ax3.plot(x,gamV_bb_pt10_v,label="$L=1,M=0$")
ax3.plot(x,gamV_bb_pt11_v,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,V,BB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamV_bb_pp00_v,label="$L=0,M=0$")
ax4.plot(x,gamV_bb_pp10_v,label="$L=1,M=0$")
ax4.plot(x,gamV_bb_pp11_v,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$\Gamma^{v,V,BB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,E,BB}_{LM,\alpha\beta}$

# %%
gamE_bb_tt20_v = f.Gamma_E_BB_v(2,0,x,lmax,0,0)
gamE_bb_tt21_v = f.Gamma_E_BB_v(2,1,x,lmax,0,0)

# %%
gamE_bb_tp20_v = f.Gamma_E_BB_v(2,0,x,lmax,0,1)
gamE_bb_tp21_v = f.Gamma_E_BB_v(2,1,x,lmax,0,1)

# %%
gamE_bb_pt20_v = f.Gamma_E_BB_v(2,0,x,lmax,1,0)
gamE_bb_pt21_v = f.Gamma_E_BB_v(2,1,x,lmax,1,0)

# %%
gamE_bb_pp20_v = f.Gamma_E_BB_v(2,0,x,lmax,1,1)
gamE_bb_pp21_v = f.Gamma_E_BB_v(2,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_bb_tt20_v,label="$L=2,M=0$")
ax1.plot(x,gamE_bb_tt21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,E,BB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_bb_tp20_v,label="$L=2,M=0$")
ax2.plot(x,gamE_bb_tp21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,E,BB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamE_bb_pt20_v,label="$L=2,M=0$")
ax3.plot(x,gamE_bb_pt21_v,label="$L=2,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,E,BB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamE_bb_pp20_v,label="$L=2,M=0$")
ax4.plot(x,gamE_bb_pp21_v,label="$L=2,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$\Gamma^{v,E,BB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,B,BB}_{LM,\alpha\beta}$

# %%
gamB_bb_tt20_v = f.Gamma_B_BB_v(2,0,x,lmax,0,0)
gamB_bb_tt21_v = f.Gamma_B_BB_v(2,1,x,lmax,0,0)

# %%
gamB_bb_tp20_v = f.Gamma_B_BB_v(2,0,x,lmax,0,1)
gamB_bb_tp21_v = f.Gamma_B_BB_v(2,1,x,lmax,0,1)

# %%
gamB_bb_pt20_v = f.Gamma_B_BB_v(2,0,x,lmax,1,0)
gamB_bb_pt21_v = f.Gamma_B_BB_v(2,1,x,lmax,1,0)

# %%
gamB_bb_pp20_v = f.Gamma_B_BB_v(2,0,x,lmax,1,1)
gamB_bb_pp21_v = f.Gamma_B_BB_v(2,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_bb_tt20_v,label="$L=2,M=0$")
ax1.plot(x,gamB_bb_tt21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,B,BB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_bb_tp20_v,label="$L=2,M=0$")
ax2.plot(x,gamB_bb_tp21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,B,BB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamB_bb_pt20_v,label="$L=2,M=0$")
ax3.plot(x,gamB_bb_pt21_v,label="$L=2,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,B,BB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamB_bb_pp20_v,label="$L=2,M=0$")
ax4.plot(x,gamB_bb_pp21_v,label="$L=2,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$\Gamma^{v,B,BB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# ### $\Gamma^{v,X,EB}_{LM,\alpha\beta}$

# %% [markdown]
# #### $\Gamma^{v,I,EB}_{LM,\alpha\beta}$

# %%
gamI_eb_tt00_v = f.Gamma_I_EB_v(0,0,x,lmax,0,0)
gamI_eb_tt10_v = f.Gamma_I_EB_v(1,0,x,lmax,0,0)
gamI_eb_tt11_v = f.Gamma_I_EB_v(1,1,x,lmax,0,0)

# %%
gamI_eb_tp00_v = f.Gamma_I_EB_v(0,0,x,lmax,0,1)
gamI_eb_tp10_v = f.Gamma_I_EB_v(1,0,x,lmax,0,1)
gamI_eb_tp11_v = f.Gamma_I_EB_v(1,1,x,lmax,0,1)

# %%
gamI_eb_pt00_v = f.Gamma_I_EB_v(0,0,x,lmax,1,0)
gamI_eb_pt10_v = f.Gamma_I_EB_v(1,0,x,lmax,1,0)
gamI_eb_pt11_v = f.Gamma_I_EB_v(1,1,x,lmax,1,0)

# %%
gamI_eb_pp00_v = f.Gamma_I_EB_v(0,0,x,lmax,1,1)
gamI_eb_pp10_v = f.Gamma_I_EB_v(1,0,x,lmax,1,1)
gamI_eb_pp11_v = f.Gamma_I_EB_v(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_eb_tt00_v,label="$L=0,M=0$")
ax1.plot(x,gamI_eb_tt10_v,label="$L=1,M=0$")
ax1.plot(x,gamI_eb_tt11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,I,EB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_eb_tp00_v,label="$L=0,M=0$")
ax2.plot(x,gamI_eb_tp10_v,label="$L=1,M=0$")
ax2.plot(x,gamI_eb_tp11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,I,EB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamI_eb_pt00_v,label="$L=0,M=0$")
ax3.plot(x,gamI_eb_pt10_v,label="$L=1,M=0$")
ax3.plot(x,gamI_eb_pt11_v,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$i\,\Gamma^{v,I,EB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamI_eb_pp00_v,label="$L=0,M=0$")
ax4.plot(x,gamI_eb_pp10_v,label="$L=1,M=0$")
ax4.plot(x,gamI_eb_pp11_v,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,I,EB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

#fig.savefig("/Users/keisuke/Documents/PTA/pta_and_astrometry/draft_pta_astrometry/draft/figs/gam_v_I_eb_2.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,V,EB}_{LM,\alpha\beta}$

# %%
gamV_eb_tt00_v = f.Gamma_V_EB_v(0,0,x,lmax,0,0)
gamV_eb_tt10_v = f.Gamma_V_EB_v(1,0,x,lmax,0,0)
gamV_eb_tt11_v = f.Gamma_V_EB_v(1,1,x,lmax,0,0)

# %%
gamV_eb_tp00_v = f.Gamma_V_EB_v(0,0,x,lmax,0,1)
gamV_eb_tp10_v = f.Gamma_V_EB_v(1,0,x,lmax,0,1)
gamV_eb_tp11_v = f.Gamma_V_EB_v(1,1,x,lmax,0,1)

# %%
gamV_eb_pt00_v = f.Gamma_V_EB_v(0,0,x,lmax,1,0)
gamV_eb_pt10_v = f.Gamma_V_EB_v(1,0,x,lmax,1,0)
gamV_eb_pt11_v = f.Gamma_V_EB_v(1,1,x,lmax,1,0)

# %%
gamV_eb_pp00_v = f.Gamma_V_EB_v(0,0,x,lmax,1,1)
gamV_eb_pp10_v = f.Gamma_V_EB_v(1,0,x,lmax,1,1)
gamV_eb_pp11_v = f.Gamma_V_EB_v(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_eb_tt00_v,label="$L=0,M=0$")
ax1.plot(x,gamV_eb_tt10_v,label="$L=1,M=0$")
ax1.plot(x,gamV_eb_tt11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,V,EB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_eb_tp00_v,label="$L=0,M=0$")
ax2.plot(x,gamV_eb_tp10_v,label="$L=1,M=0$")
ax2.plot(x,gamV_eb_tp11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,V,EB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamV_eb_pt00_v,label="$L=0,M=0$")
ax3.plot(x,gamV_eb_pt10_v,label="$L=1,M=0$")
ax3.plot(x,gamV_eb_pt11_v,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$i\,\Gamma^{v,V,EB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamV_eb_pp00_v,label="$L=0,M=0$")
ax4.plot(x,gamV_eb_pp10_v,label="$L=1,M=0$")
ax4.plot(x,gamV_eb_pp11_v,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,V,EB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,E,EB}_{LM,\alpha\beta}$

# %%
gamE_eb_tt20_v = f.Gamma_E_EB_v(2,0,x,lmax,0,0)
gamE_eb_tt21_v = f.Gamma_E_EB_v(2,1,x,lmax,0,0)

# %%
gamE_eb_tp20_v = f.Gamma_E_EB_v(2,0,x,lmax,0,1)
gamE_eb_tp21_v = f.Gamma_E_EB_v(2,1,x,lmax,0,1)

# %%
gamE_eb_pt20_v = f.Gamma_E_EB_v(2,0,x,lmax,1,0)
gamE_eb_pt21_v = f.Gamma_E_EB_v(2,1,x,lmax,1,0)

# %%
gamE_eb_pp20_v = f.Gamma_E_EB_v(2,0,x,lmax,1,1)
gamE_eb_pp21_v = f.Gamma_E_EB_v(2,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_eb_tt20_v,label="$L=2,M=0$")
ax1.plot(x,gamE_eb_tt21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,E,EB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_eb_tp20_v,label="$L=2,M=0$")
ax2.plot(x,gamE_eb_tp21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,E,EB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamE_eb_pt20_v,label="$L=2,M=0$")
ax3.plot(x,gamE_eb_pt21_v,label="$L=2,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$i\,\Gamma^{v,E,EB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamE_eb_pp20_v,label="$L=2,M=0$")
ax4.plot(x,gamE_eb_pp21_v,label="$L=2,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,E,EB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,B,EB}_{LM,\alpha\beta}$

# %%
gamB_eb_tt20_v = f.Gamma_B_EB_v(2,0,x,lmax,0,0)
gamB_eb_tt21_v = f.Gamma_B_EB_v(2,1,x,lmax,0,0)

# %%
gamB_eb_tp20_v = f.Gamma_B_EB_v(2,0,x,lmax,0,1)
gamB_eb_tp21_v = f.Gamma_B_EB_v(2,1,x,lmax,0,1)

# %%
gamB_eb_pt20_v = f.Gamma_B_EB_v(2,0,x,lmax,1,0)
gamB_eb_pt21_v = f.Gamma_B_EB_v(2,1,x,lmax,1,0)

# %%
gamB_eb_pp20_v = f.Gamma_B_EB_v(2,0,x,lmax,1,1)
gamB_eb_pp21_v = f.Gamma_B_EB_v(2,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_eb_tt20_v,label="$L=2,M=0$")
ax1.plot(x,gamB_eb_tt21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,B,EB}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_eb_tp20_v,label="$L=2,M=0$")
ax2.plot(x,gamB_eb_tp21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$-i\,\Gamma^{v,B,EB}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamB_eb_pt20_v,label="$L=2,M=0$")
ax3.plot(x,gamB_eb_pt21_v,label="$L=2,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$i\,\Gamma^{v,B,EB}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamB_eb_pp20_v,label="$L=2,M=0$")
ax4.plot(x,gamB_eb_pp21_v,label="$L=2,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$\Gamma^{v,B,EB}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# ### $\Gamma^{v,X,BE}_{LM,\alpha\beta}$

# %% [markdown]
# #### $\Gamma^{v,I,BE}_{LM,\alpha\beta}$

# %%
gamI_be_tt00_v = f.Gamma_I_BE_v(0,0,x,lmax,0,0)
gamI_be_tt10_v = f.Gamma_I_BE_v(1,0,x,lmax,0,0)
gamI_be_tt11_v = f.Gamma_I_BE_v(1,1,x,lmax,0,0)

# %%
gamI_be_tp00_v = f.Gamma_I_BE_v(0,0,x,lmax,0,1)
gamI_be_tp10_v = f.Gamma_I_BE_v(1,0,x,lmax,0,1)
gamI_be_tp11_v = f.Gamma_I_BE_v(1,1,x,lmax,0,1)

# %%
gamI_be_pt00_v = f.Gamma_I_BE_v(0,0,x,lmax,1,0)
gamI_be_pt10_v = f.Gamma_I_BE_v(1,0,x,lmax,1,0)
gamI_be_pt11_v = f.Gamma_I_BE_v(1,1,x,lmax,1,0)

# %%
gamI_be_pp00_v = f.Gamma_I_BE_v(0,0,x,lmax,1,1)
gamI_be_pp10_v = f.Gamma_I_BE_v(1,0,x,lmax,1,1)
gamI_be_pp11_v = f.Gamma_I_BE_v(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamI_be_tt00_v,label="$L=0,M=0$")
ax1.plot(x,gamI_be_tt10_v,label="$L=1,M=0$")
ax1.plot(x,gamI_be_tt11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,I,BE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamI_be_tp00_v,label="$L=0,M=0$")
ax2.plot(x,gamI_be_tp10_v,label="$L=1,M=0$")
ax2.plot(x,gamI_be_tp11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$i\,\Gamma^{v,I,BE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamI_be_pt00_v,label="$L=0,M=0$")
ax3.plot(x,gamI_be_pt10_v,label="$L=1,M=0$")
ax3.plot(x,gamI_be_pt11_v,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,I,BE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamI_be_pp00_v,label="$L=0,M=0$")
ax4.plot(x,gamI_be_pp10_v,label="$L=1,M=0$")
ax4.plot(x,gamI_be_pp11_v,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,I,BE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,V,BE}_{LM,\alpha\beta}$

# %%
gamV_be_tt00_v = f.Gamma_V_BE_v(0,0,x,lmax,0,0)
gamV_be_tt10_v = f.Gamma_V_BE_v(1,0,x,lmax,0,0)
gamV_be_tt11_v = f.Gamma_V_BE_v(1,1,x,lmax,0,0)

# %%
gamV_be_tp00_v = f.Gamma_V_BE_v(0,0,x,lmax,0,1)
gamV_be_tp10_v = f.Gamma_V_BE_v(1,0,x,lmax,0,1)
gamV_be_tp11_v = f.Gamma_V_BE_v(1,1,x,lmax,0,1)

# %%
gamV_be_pt00_v = f.Gamma_V_BE_v(0,0,x,lmax,1,0)
gamV_be_pt10_v = f.Gamma_V_BE_v(1,0,x,lmax,1,0)
gamV_be_pt11_v = f.Gamma_V_BE_v(1,1,x,lmax,1,0)

# %%
gamV_be_pp00_v = f.Gamma_V_BE_v(0,0,x,lmax,1,1)
gamV_be_pp10_v = f.Gamma_V_BE_v(1,0,x,lmax,1,1)
gamV_be_pp11_v = f.Gamma_V_BE_v(1,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamV_be_tt00_v,label="$L=0,M=0$")
ax1.plot(x,gamV_be_tt10_v,label="$L=1,M=0$")
ax1.plot(x,gamV_be_tt11_v,label="$L=1,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,V,BE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamV_be_tp00_v,label="$L=0,M=0$")
ax2.plot(x,gamV_be_tp10_v,label="$L=1,M=0$")
ax2.plot(x,gamV_be_tp11_v,label="$L=1,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$i\,\Gamma^{v,V,BE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamV_be_pt00_v,label="$L=0,M=0$")
ax3.plot(x,gamV_be_pt10_v,label="$L=1,M=0$")
ax3.plot(x,gamV_be_pt11_v,label="$L=1,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,V,BE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamV_be_pp00_v,label="$L=0,M=0$")
ax4.plot(x,gamV_be_pp10_v,label="$L=1,M=0$")
ax4.plot(x,gamV_be_pp11_v,label="$L=1,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,V,BE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,E,BE}_{LM,\alpha\beta}$

# %%
gamE_be_tt20_v = f.Gamma_E_BE_v(2,0,x,lmax,0,0)
gamE_be_tt21_v = f.Gamma_E_BE_v(2,1,x,lmax,0,0)

# %%
gamE_be_tp20_v = f.Gamma_E_BE_v(2,0,x,lmax,0,1)
gamE_be_tp21_v = f.Gamma_E_BE_v(2,1,x,lmax,0,1)

# %%
gamE_be_pt20_v = f.Gamma_E_BE_v(2,0,x,lmax,1,0)
gamE_be_pt21_v = f.Gamma_E_BE_v(2,1,x,lmax,1,0)

# %%
gamE_be_pp20_v = f.Gamma_E_BE_v(2,0,x,lmax,1,1)
gamE_be_pp21_v = f.Gamma_E_BE_v(2,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamE_be_tt20_v,label="$L=2,M=0$")
ax1.plot(x,gamE_be_tt21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,E,BE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamE_be_tp20_v,label="$L=2,M=0$")
ax2.plot(x,gamE_be_tp21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$i\,\Gamma^{v,E,BE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamE_be_pt20_v,label="$L=2,M=0$")
ax3.plot(x,gamE_be_pt21_v,label="$L=2,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,E,BE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamE_be_pp20_v,label="$L=2,M=0$")
ax4.plot(x,gamE_be_pp21_v,label="$L=2,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,E,BE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### $\Gamma^{v,B,BE}_{LM,\alpha\beta}$

# %%
gamB_be_tt20_v = f.Gamma_B_BE_v(2,0,x,lmax,0,0)
gamB_be_tt21_v = f.Gamma_B_BE_v(2,1,x,lmax,0,0)

# %%
gamB_be_tp20_v = f.Gamma_B_BE_v(2,0,x,lmax,0,1)
gamB_be_tp21_v = f.Gamma_B_BE_v(2,1,x,lmax,0,1)

# %%
gamB_be_pt20_v = f.Gamma_B_BE_v(2,0,x,lmax,1,0)
gamB_be_pt21_v = f.Gamma_B_BE_v(2,1,x,lmax,1,0)

# %%
gamB_be_pp20_v = f.Gamma_B_BE_v(2,0,x,lmax,1,1)
gamB_be_pp21_v = f.Gamma_B_BE_v(2,1,x,lmax,1,1)

# %%
fig = plt.figure(figsize = (12,8),tight_layout=True)
#add_subplot(row,column,place)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

bbox_dict = dict(edgecolor="black",facecolor="white")

ax1.plot(x,gamB_be_tt20_v,label="$L=2,M=0$")
ax1.plot(x,gamB_be_tt21_v,label="$L=2,M=1$")

ax1.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax1.set_ylabel("$-\Gamma^{v,B,BE}_{LM,\\theta\\theta}$")
fig.subplots_adjust(bottom=0.)
ax1.legend(loc='upper left')

ax2.plot(x,gamB_be_tp20_v,label="$L=2,M=0$")
ax2.plot(x,gamB_be_tp21_v,label="$L=2,M=1$")

ax2.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax2.set_ylabel("$i\,\Gamma^{v,B,BE}_{LM,\\theta\phi}$")
fig.subplots_adjust(bottom=0.)
ax2.legend(loc='upper left')

ax3.plot(x,gamB_be_pt20_v,label="$L=2,M=0$")
ax3.plot(x,gamB_be_pt21_v,label="$L=2,M=1$")

ax3.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax3.set_ylabel("$-i\,\Gamma^{v,B,BE}_{LM,\phi\\theta}$")
fig.subplots_adjust(bottom=0.)
ax3.legend(loc='upper left')

ax4.plot(x,gamB_be_pp20_v,label="$L=2,M=0$")
ax4.plot(x,gamB_be_pp21_v,label="$L=2,M=1$")

ax4.set_xlabel("$\\theta\,[\mathrm{rad}]$")
ax4.set_ylabel("$-\Gamma^{v,B,BE}_{LM,\phi\phi}$")
fig.subplots_adjust(bottom=0.)
ax4.legend(loc='upper left')

plt.show()
